# %%
import pandas as pd
import json
import requests

# %%
query="아이폰13"
url = f'https://search-api.joongna.com/v25/search/product'
data = {
    "filter":{
#         "categoryDepth":0,
#         "categorySeq":0,
        "dateFilterParameter":{
            "sortEndDate":"2022-04-15",
            "sortStartDate":"2022-04-13"
        },
        "productCondition":-1,
        "flawedYn":0,
        "fullPackageYn":0,
        "limitedEditionYn":0,
        "maxPrice":2000000000,
        "minPrice":0,
        "tradeType":0
    },
    "page":0,
    "firstQuantity":10000,
    "productFilter":"ALL",
    "productStates":[
#         0,
#         1,
        99
    ],
    "quantity":10000,
    "searchQuantity":10000,
    "osType":2,
    "searchWord":"아이폰13",
    "sort":"RECENT_SORT",
    "startIndex":0,
#     "searchStartTime":"2022-04-15 14:55:21"
}

# %%
data_page={
    "filter":{
        "categoryDepth":0,
        "categorySeq":0,
        "dateFilterParameter":{
            "sortEndDate":"2022-04-15",
            "sortStartDate":"2022-04-14"
        },
        "productCondition":-1,
        "flawedYn":0,
        "fullPackageYn":0,
        "limitedEditionYn":0,
        "maxPrice":2000000000,
        "minPrice":0,
        "tradeType":0
    },
    "page":21,
    "firstQuantity":10,
    "productFilter":"ALL",
    "productStates":[
        0,
        1
    ],
    "quantity":10,
    "searchQuantity":10,
    "osType":2,
    "searchWord":"아이폰13",
    "sort":"RECENT_SORT",
    "startIndex":21,
    "searchStartTime":"2022-04-15 16:42:07"
}

# %%
n={
    "filter":{
        "categoryDepth":0,
        "categorySeq":0,
        "dateFilterParameter":{
            "sortEndDate":"2022-04-15",
            "sortStartDate":"2022-04-14"
        },
        "productCondition":-1,
        "flawedYn":0,
        "fullPackageYn":0,
        "limitedEditionYn":0,
        "maxPrice":2000000000,
        "minPrice":0,
        "tradeType":0
    },
    "page":22,
    "firstQuantity":10,
    "productFilter":"ALL",
    "productStates":[
        0,
        1
    ],
    "quantity":10,
    "searchQuantity":10,
    "osType":2,
    "searchWord":"아이폰13",
    "sort":"RECENT_SORT",
    "startIndex":22,
    "searchStartTime":"2022-04-15 16:43:24"
}

# %%
#json.dumps
response= requests.post(url,json=(data))
data=response.json()['data']

# %%
len(data['items'])
# Out:
# 4043

# %%
data['items']
# Out:
# [{'seq': 0,
#   'productPositionNo': 1,
#   'highlightedTitle': '[24시]<em>아이폰</em><em>13</em> 미니 <em>13</em>프로 맥스 (애플/삼성전기종 최고가매입)',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910956896&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910956896,
#   'articleRegDate': '2022-04-15 17:14:35',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650010494390_527047e0-598b-4a15-a3df-186e34fd9b64.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 100000000,
#   'state': 0,
#   'title': '[24시]아이폰13 미니 13프로 맥스 (애플/삼성전기종 최고가매입)',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:14:35',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 2,
#   'highlightedTitle': '<em>아이폰</em><em>13</em> PRO MAX 프로 맥스 자급제미개봉,당일개통,박스폰삽니다',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910956688&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910956688,
#   'articleRegDate': '2022-04-15 17:13:35',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650010431833_121bc2db-667d-4200-b1b3-ec51ce47a1c5.png?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 4999999,
#   'state': 0,
#   'title': '아이폰13 PRO MAX 프로 맥스 자급제미개봉,당일개통,박스폰삽니다',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:13:35',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 3,
#   'highlightedTitle': '부산 <em>아이폰</em><em>13</em>프로맥스 실버 미개봉 새상품 256G',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=424&boardtype=C&page=1&articleid=910956320&referrerAllArticles=false',
#   'menuId': 424,
#   'articleSeq': 910956320,
#   'articleRegDate': '2022-04-15 17:11:38',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650010312886_7acf0355-dd9f-49d6-81a3-15dee1026414.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 140000,
#   'state': 0,
#   'title': '부산 아이폰13프로맥스 실버 미개봉 새상품 256G ',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:11:38',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 4,
#   'highlightedTitle': '<em>아이폰</em><em>13</em> 핑크 128기가 미개봉 자급제 팝니다',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910956303&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910956303,
#   'articleRegDate': '2022-04-15 17:11:33',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650010314556_2244c5f7-73b7-4ad2-880b-8e86ad447731.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 940002,
#   'state': 0,
#   'title': '아이폰13 핑크 128기가 미개봉 자급제 팝니다',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:11:33',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 5,
#   'highlightedTitle': '[매입]<em>아이폰</em><em>13</em> 프로 맥스 애플전기종,중고폰,자급제미개봉,박스폰매입',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910956291&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910956291,
#   'articleRegDate': '2022-04-15 17:11:28',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650010313794_a73cb1be-4c87-4a29-a9a1-1528640af86a.png?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 1500000,
#   'state': 0,
#   'title': '[매입]아이폰13 프로 맥스 애플전기종,중고폰,자급제미개봉,박스폰매입',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:11:28',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 39139734,
#   'productPositionNo': 6,
#   'highlightedTitle': '<em>아이폰</em><em>13</em>프로 256GB 그래파이트 팝니다 울산중고폰',
#   'storeSeq': 3192941,
#   'platformType': 1,
#   'storeProfileUrl': 'https://img2.joongna.com/media/original/2020/03/27/15852968318088BR_Z86eU.jpg?impolicy=thumb&size=50',
#   'storeNickname': '울산중고폰마켓JJ',
#   'userName': '울산중고폰마켓JJ',
#   'detailImgUrl': 'https://img2.joongna.com/media/original/2022/04/12/1649748464493o3g_cMFEA.jpg?impolicy=resizeWatermark3',
#   'mainLocationName': '',
#   'locationNames': [],
#   'articleUrl': None,
#   'menuId': None,
#   'articleSeq': None,
#   'articleRegDate': '2022-04-15 17:10:37',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/media/original/2022/04/12/1649748464493o3g_cMFEA.jpg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 1150000,
#   'state': 0,
#   'title': '아이폰13프로 256GB 그래파이트 팝니다 울산중고폰',
#   'subTitle': '',
#   'sortDate': '2022-04-15 17:10:37',
#   'userSeq': 3192941,
#   'videoUrl': '',
#   'viewCount': 1,
#   'videoProductYn': 'N',
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 7,
#   'highlightedTitle': '<em>아이폰</em><em>13</em>프로 맥스 미니 갤럭시S22 자급제 통신사 유심기변 전기종 삽니다.',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910955994&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910955994,
#   'articleRegDate': '2022-04-15 17:09:56',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650010256028_46b11a38-42cd-482e-a557-3cc4cd1d5862.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 3000,
#   'state': 0,
#   'title': '아이폰13프로 맥스 미니 갤럭시S22 자급제 통신사 유심기변 전기종 삽니다.',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:09:56',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 8,
#   'highlightedTitle': '<em>아이폰</em>,갤럭시(자급제,박스폰,중고폰매입)당일매입[<em>13</em>프로맥스,S22',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=424&boardtype=C&page=1&articleid=910955826&referrerAllArticles=false',
#   'menuId': 424,
#   'articleSeq': 910955826,
#   'articleRegDate': '2022-04-15 17:09:05',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650010198363_57a68689-ca0d-401a-afb7-9655f144a202.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 2000000,
#   'state': 0,
#   'title': '아이폰,갤럭시(자급제,박스폰,중고폰매입)당일매입[13프로맥스,S22',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:09:05',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 9,
#   'highlightedTitle': '<em>아이폰</em><em>13</em> PRO MAX 프로 맥스 자급제미개봉,당일개통,박스폰삽니다',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910955557&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910955557,
#   'articleRegDate': '2022-04-15 17:07:41',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650010138632_df2cddd8-aab0-43a4-bc22-687bce69bc97.png?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 4999999,
#   'state': 0,
#   'title': '아이폰13 PRO MAX 프로 맥스 자급제미개봉,당일개통,박스폰삽니다',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:07:41',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 10,
#   'highlightedTitle': '<em>아이폰</em><em>13</em> 프로맥스/프로 pro max 최고가매입(자급제,중고폰)',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910955539&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910955539,
#   'articleRegDate': '2022-04-15 17:07:35',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650010072656_7103dd05-734f-4f9a-afb4-7132644cfd68.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 2999000,
#   'state': 0,
#   'title': '아이폰13 프로맥스/프로 pro max 최고가매입(자급제,중고폰)',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:07:35',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 11,
#   'highlightedTitle': '[매입]<em>아이폰</em> <em>13</em> 프로 맥스(자급제폰,박스폰,당일개통폰,중고폰)',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910955395&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910955395,
#   'articleRegDate': '2022-04-15 17:06:46',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650010069817_78d9d0a4-0a65-4487-a207-238304a43a8b.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 3333333,
#   'state': 0,
#   'title': '[매입]아이폰 13 프로 맥스(자급제폰,박스폰,당일개통폰,중고폰)',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:06:46',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 12,
#   'highlightedTitle': '45170 <em>아이폰</em>7 블랙 32GB 배터리100% <em>13</em>만원에 판매합니다',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910955289&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910955289,
#   'articleRegDate': '2022-04-15 17:06:06',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650010015770_97b67fdd-9d8e-401b-a912-bf0b9d60f822.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 130000,
#   'state': 0,
#   'title': '45170 아이폰7 블랙 32GB 배터리100% 13만원에 판매합니다',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:06:06',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 13,
#   'highlightedTitle': '53245 <em>아이폰</em><em>13</em> 스타라이트 256GB 배터리100% 공기계 팝니다 81만원',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=424&boardtype=C&page=1&articleid=910955112&referrerAllArticles=false',
#   'menuId': 424,
#   'articleSeq': 910955112,
#   'articleRegDate': '2022-04-15 17:05:08',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009956217_d9d07180-b31d-4dda-9729-3669b5fff776.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 810000,
#   'state': 0,
#   'title': '53245 아이폰13 스타라이트 256GB 배터리100% 공기계 팝니다 81만원',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:05:08',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 14,
#   'highlightedTitle': 'S급 <em>아이폰</em> <em>13</em> 256GB 핑크 성능 촤대치 100%',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=424&boardtype=C&page=1&articleid=910955031&referrerAllArticles=false',
#   'menuId': 424,
#   'articleSeq': 910955031,
#   'articleRegDate': '2022-04-15 17:04:41',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009951979_cf2b8ed6-4773-4454-9f19-c3275b57fc75.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 900000,
#   'state': 0,
#   'title': 'S급 아이폰 13 256GB 핑크 성능 촤대치 100%',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:04:41',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 15,
#   'highlightedTitle': '(새상품급)<em>아이폰</em><em>13</em>미니 128기가 블랙 배터리100% 69만원 판매해요',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910954886&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910954886,
#   'articleRegDate': '2022-04-15 17:03:48',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009895364_06c92582-76f3-4b1f-99da-6d271af25dc5.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 690000,
#   'state': 0,
#   'title': '(새상품급)아이폰13미니 128기가 블랙 배터리100% 69만원 판매해요',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:03:48',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 36162863,
#   'productPositionNo': 16,
#   'highlightedTitle': '[새상품] 프라다케이스<em>아이폰</em><em>13</em>케이스 명품카드지갑케이스',
#   'storeSeq': 103000,
#   'platformType': 1,
#   'storeProfileUrl': 'https://ssl.pstatic.net/static/pwe/address/deskhome/ico_default1.jpg',
#   'storeNickname': '레고레고상점',
#   'userName': '레고레고상점',
#   'detailImgUrl': 'https://img2.joongna.com/media/original/2022/03/31/1648714754799E9N_JwB60.jpg?impolicy=resizeWatermark3',
#   'mainLocationName': '',
#   'locationNames': [],
#   'articleUrl': None,
#   'menuId': None,
#   'articleSeq': None,
#   'articleRegDate': '2022-04-15 17:03:40',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/media/original/2022/03/31/1648714754799E9N_JwB60.jpg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 20000,
#   'state': 0,
#   'title': '[새상품] 프라다케이스아이폰13케이스 명품카드지갑케이스',
#   'subTitle': '',
#   'sortDate': '2022-04-15 17:03:40',
#   'userSeq': 103000,
#   'videoUrl': '',
#   'viewCount': 6,
#   'videoProductYn': 'N',
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 37188792,
#   'productPositionNo': 17,
#   'highlightedTitle': '[새상품]<em>아이폰</em><em>13</em>프로케이스 <em>아이폰</em><em>13</em>pro케이스 구찌',
#   'storeSeq': 103000,
#   'platformType': 1,
#   'storeProfileUrl': 'https://ssl.pstatic.net/static/pwe/address/deskhome/ico_default1.jpg',
#   'storeNickname': '레고레고상점',
#   'userName': '레고레고상점',
#   'detailImgUrl': 'https://img2.joongna.com/media/original/2022/04/05/1649161392814R4O_8bLSc.jpg?impolicy=resizeWatermark3',
#   'mainLocationName': '',
#   'locationNames': [],
#   'articleUrl': None,
#   'menuId': None,
#   'articleSeq': None,
#   'articleRegDate': '2022-04-15 17:03:34',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/media/original/2022/04/05/1649161392814R4O_8bLSc.jpg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 20000,
#   'state': 0,
#   'title': '[새상품]아이폰13프로케이스 아이폰13pro케이스 구찌',
#   'subTitle': '',
#   'sortDate': '2022-04-15 17:03:34',
#   'userSeq': 103000,
#   'videoUrl': '',
#   'viewCount': 4,
#   'videoProductYn': 'N',
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 18,
#   'highlightedTitle': '53245 <em>아이폰</em><em>13</em> 스타라이트 256GB 배터리100% 공기계 팝니다 81만원',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910954509&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910954509,
#   'articleRegDate': '2022-04-15 17:01:39',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009773603_bd48b9fb-4f37-4be6-905a-b1c72e894fec.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 810000,
#   'state': 0,
#   'title': '53245 아이폰13 스타라이트 256GB 배터리100% 공기계 팝니다 81만원',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:01:39',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 19,
#   'highlightedTitle': '<em>아이폰</em><em>13</em> 128기가 듀얼심',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910954302&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910954302,
#   'articleRegDate': '2022-04-15 17:00:27',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009654575_c1f019bb-afa3-49b7-b8d8-c8674b0bfcdd.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 900000,
#   'state': 0,
#   'title': '아이폰13 128기가 듀얼심',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:00:27',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 20,
#   'highlightedTitle': '[매입]<em>아이폰</em> <em>13</em> 프로 맥스(자급제폰,박스폰,당일개통폰,중고폰)',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910954278&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910954278,
#   'articleRegDate': '2022-04-15 17:00:22',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009659133_074a3379-a04e-4032-a9b1-22ab059dab4f.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 3333333,
#   'state': 0,
#   'title': '[매입]아이폰 13 프로 맥스(자급제폰,박스폰,당일개통폰,중고폰)',
#   'subTitle': None,
#   'sortDate': '2022-04-15 17:00:22',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 21,
#   'highlightedTitle': '[매입]<em>아이폰</em><em>13</em>,<em>아이폰</em>전기종 자급제,박스폰,중고폰,파손폰 당일매입',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910954196&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910954196,
#   'articleRegDate': '2022-04-15 16:59:57',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009656743_c5328ed7-0d44-4426-ad44-1f76c0978e68.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 1000000,
#   'state': 0,
#   'title': '[매입]아이폰13,아이폰전기종 자급제,박스폰,중고폰,파손폰 당일매입',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:59:57',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 22,
#   'highlightedTitle': '<em>아이폰</em><em>13</em> 12 미니 mini 11 프로맥스 자급제 매입 삽니다',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=424&boardtype=C&page=1&articleid=910954115&referrerAllArticles=false',
#   'menuId': 424,
#   'articleSeq': 910954115,
#   'articleRegDate': '2022-04-15 16:59:29',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009595118_1ff3167b-c3cc-41b7-867e-376121e55bcd.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 1000000,
#   'state': 0,
#   'title': '아이폰13 12 미니 mini 11 프로맥스 자급제 매입 삽니다',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:59:29',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 23,
#   'highlightedTitle': '<em>아이폰</em>전기종(자급제,박스폰,중고폰,유심기변)매입[<em>아이폰</em><em>13</em>프로맥스]',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=424&boardtype=C&page=1&articleid=910954065&referrerAllArticles=false',
#   'menuId': 424,
#   'articleSeq': 910954065,
#   'articleRegDate': '2022-04-15 16:59:11',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009597402_147cb6f4-a0e3-46fc-8f0a-734687ba799e.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 2000000,
#   'state': 0,
#   'title': '아이폰전기종(자급제,박스폰,중고폰,유심기변)매입[아이폰13프로맥스]',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:59:11',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 24,
#   'highlightedTitle': '아더에러 casetify 콜라보 케이스 팔아요 <em>아이폰</em> <em>13</em> 겔플3',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=787&boardtype=C&page=1&articleid=910953902&referrerAllArticles=false',
#   'menuId': 787,
#   'articleSeq': 910953902,
#   'articleRegDate': '2022-04-15 16:58:13',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009537002_36da6acd-3189-4f06-a41b-92fccd365cec.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 130000,
#   'state': 0,
#   'title': '아더에러 casetify 콜라보 케이스 팔아요 아이폰 13 겔플3',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:58:13',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 25,
#   'highlightedTitle': '<em>아이폰</em><em>13</em>미니 스타라이트 128용량 새상품컨디션 초S급 70만 판매해요',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910953758&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910953758,
#   'articleRegDate': '2022-04-15 16:57:17',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009474625_6f9c3ba6-1fdd-4653-a51f-1c742b688897.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 700000,
#   'state': 0,
#   'title': '아이폰13미니 스타라이트 128용량 새상품컨디션 초S급 70만 판매해요',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:57:17',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 26,
#   'highlightedTitle': '<em>아이폰</em> <em>13</em> 프로 256GB 시에라블루 팝니다',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910953671&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910953671,
#   'articleRegDate': '2022-04-15 16:56:46',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009478108_f92f2333-da27-4e80-9745-df18a8f051d6.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 1100000,
#   'state': 0,
#   'title': '아이폰 13 프로 256GB 시에라블루 팝니다',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:56:46',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 27,
#   'highlightedTitle': '<em>아이폰</em>,갤럭시(자급제,박스폰,중고폰매입)당일매입[<em>13</em>프로맥스,S22',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=424&boardtype=C&page=1&articleid=910953578&referrerAllArticles=false',
#   'menuId': 424,
#   'articleSeq': 910953578,
#   'articleRegDate': '2022-04-15 16:56:19',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009417719_b5723b10-5c9f-465f-bbec-62a462d821cf.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 2000000,
#   'state': 0,
#   'title': '아이폰,갤럭시(자급제,박스폰,중고폰매입)당일매입[13프로맥스,S22',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:56:19',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 28,
#   'highlightedTitle': '<em>아이폰</em><em>13</em> 블랙 128g 자급제 팝니다',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910953577&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910953577,
#   'articleRegDate': '2022-04-15 16:56:18',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009417787_1f630aaa-0e04-42f2-bfd7-445da5366830.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 850000,
#   'state': 0,
#   'title': '아이폰13 블랙 128g 자급제 팝니다',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:56:18',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 29,
#   'highlightedTitle': '아더에러x케이스티파이 <em>아이폰</em><em>13</em>프로 케이스 판매합니다.',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=427&boardtype=C&page=1&articleid=910953563&referrerAllArticles=false',
#   'menuId': 427,
#   'articleSeq': 910953563,
#   'articleRegDate': '2022-04-15 16:56:14',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009418279_8e7209e0-2d11-46b1-ae23-813cefa4c665.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 90000,
#   'state': 0,
#   'title': '아더에러x케이스티파이 아이폰13프로 케이스 판매합니다.',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:56:14',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 30,
#   'highlightedTitle': '<em>아이폰</em><em>13</em>프로 블루포크 실리콘 케이스,클리어 케이스 팝니다',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910953538&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910953538,
#   'articleRegDate': '2022-04-15 16:56:06',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009417617_13c38ee7-85a2-4584-8774-195bd84e2057.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 85000,
#   'state': 0,
#   'title': '아이폰13프로 블루포크 실리콘 케이스,클리어 케이스 팝니다',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:56:06',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 31,
#   'highlightedTitle': '[매입]<em>아이폰</em><em>13</em>,폴드,플립전기종 자급제,박스폰,중고폰 당일매입',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=424&boardtype=C&page=1&articleid=910953105&referrerAllArticles=false',
#   'menuId': 424,
#   'articleSeq': 910953105,
#   'articleRegDate': '2022-04-15 16:53:53',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009293136_e2924869-aa3b-4170-8a22-152e4ce4718b.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 2000000,
#   'state': 0,
#   'title': '[매입]아이폰13,폴드,플립전기종 자급제,박스폰,중고폰 당일매입',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:53:53',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 32,
#   'highlightedTitle': '미개봉 <em>아이폰</em><em>13</em>미니128 그린',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910952984&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910952984,
#   'articleRegDate': '2022-04-15 16:53:13',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009236745_5e4040a8-5fc6-4a95-927c-c6a720532d62.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 810000,
#   'state': 0,
#   'title': '미개봉 아이폰13미니128 그린',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:53:13',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 33,
#   'highlightedTitle': '차량용 무선충전기 맥세이프 호환/ <em>아이폰</em> 12,<em>13</em>시리즈 전용',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=427&boardtype=C&page=1&articleid=910952942&referrerAllArticles=false',
#   'menuId': 427,
#   'articleSeq': 910952942,
#   'articleRegDate': '2022-04-15 16:52:59',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009238320_6abfcd89-0722-4150-b49a-c5bec8346e62.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 23500,
#   'state': 0,
#   'title': '차량용 무선충전기 맥세이프 호환/ 아이폰 12,13시리즈 전용',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:52:59',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 34,
#   'highlightedTitle': '[매입]<em>아이폰</em><em>13</em> 프로 맥스 애플전기종,중고폰,자급제미개봉,박스폰매입',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910952882&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910952882,
#   'articleRegDate': '2022-04-15 16:52:40',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009236195_c8332eed-2850-445c-af97-f111d5c4b5cd.png?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 1500000,
#   'state': 0,
#   'title': '[매입]아이폰13 프로 맥스 애플전기종,중고폰,자급제미개봉,박스폰매입',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:52:40',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 36500511,
#   'productPositionNo': 35,
#   'highlightedTitle': '차량용 무선충전기 맥세이프케이스호환/ <em>아이폰</em>12,<em>13</em>',
#   'storeSeq': 1120524,
#   'platformType': 1,
#   'storeProfileUrl': 'https://img2.joongna.com/media/original/2022/02/15/1644928922712LKw_4NtIi.jpg?impolicy=thumb&size=50',
#   'storeNickname': '뽀글popo',
#   'userName': '뽀글popo',
#   'detailImgUrl': 'https://img2.joongna.com/media/original/2022/03/31/1648730492127q5e_5XasY.jpg?impolicy=resizeWatermark3',
#   'mainLocationName': '월평3동',
#   'locationNames': ['대전광역시 서구 월평3동', '갈마역'],
#   'articleUrl': None,
#   'menuId': None,
#   'articleSeq': None,
#   'articleRegDate': '2022-04-15 16:51:42',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/media/original/2022/03/31/1648730492127q5e_5XasY.jpg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 23500,
#   'state': 0,
#   'title': '차량용 무선충전기 맥세이프케이스호환/ 아이폰12,13',
#   'subTitle': '',
#   'sortDate': '2022-04-15 16:51:42',
#   'userSeq': 1120524,
#   'videoUrl': '',
#   'viewCount': 19,
#   'videoProductYn': 'N',
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 36,
#   'highlightedTitle': '(195991)<em>아이폰</em><em>13</em>미니 128기가 핑크 SS급 70만원',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=424&boardtype=C&page=1&articleid=910952476&referrerAllArticles=false',
#   'menuId': 424,
#   'articleSeq': 910952476,
#   'articleRegDate': '2022-04-15 16:50:21',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009060743_1a475722-3043-4ea7-9e18-e8caf644fc77.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 2000,
#   'state': 0,
#   'title': '(195991)아이폰13미니 128기가 핑크 SS급 70만원',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:50:21',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 37,
#   'highlightedTitle': '<em>아이폰</em><em>13</em> PRO MAX 프로 맥스 자급제미개봉,당일개통,박스폰삽니다',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910952401&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910952401,
#   'articleRegDate': '2022-04-15 16:49:58',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650009055875_8c2ead0b-a831-4726-a349-7cda385002c7.png?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 4999999,
#   'state': 0,
#   'title': '아이폰13 PRO MAX 프로 맥스 자급제미개봉,당일개통,박스폰삽니다',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:49:58',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 38,
#   'highlightedTitle': '<em>아이폰</em><em>13</em> 프로 맥스 갤럭시S22 울트라 전기종 삽니다. 자급제 통신사 유심기변',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=424&boardtype=C&page=1&articleid=910952008&referrerAllArticles=false',
#   'menuId': 424,
#   'articleSeq': 910952008,
#   'articleRegDate': '2022-04-15 16:48:05',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650008937212_1eea1e0d-aaea-410b-9507-aedca0b681bc.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 1550000,
#   'state': 0,
#   'title': '아이폰13 프로 맥스 갤럭시S22 울트라 전기종 삽니다. 자급제 통신사 유심기변',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:48:05',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 39,
#   'highlightedTitle': '[매입]<em>아이폰</em><em>13</em> 프로 맥스 애플전기종,중고폰,자급제미개봉,박스폰매입',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910951722&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910951722,
#   'articleRegDate': '2022-04-15 16:46:24',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650008814710_3c800ffc-2f1f-4cac-bfc8-3863bf070e69.png?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 1500000,
#   'state': 0,
#   'title': '[매입]아이폰13 프로 맥스 애플전기종,중고폰,자급제미개봉,박스폰매입',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:46:24',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 40,
#   'highlightedTitle': '(자급제)<em>아이폰</em><em>13</em>미니 128기가 블랙 풀박스 새상품 72만원 판매',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910951535&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910951535,
#   'articleRegDate': '2022-04-15 16:45:15',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650008758102_ffc4a7f2-0b80-40a4-a767-0324752d8a5e.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 720000,
#   'state': 0,
#   'title': '(자급제)아이폰13미니 128기가 블랙 풀박스 새상품 72만원 판매',
#   'subTitle': None,
#   'sortDate': '2022-04-15 16:45:15',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 41,
#   'highlightedTitle': '[24시]<em>아이폰</em><em>13</em> 미니 <em>13</em>프로 맥스 (애플/삼성전기종 최고가매입)',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910951354&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910951354,
#   'articleRegDate': '2022-04-15 16:44:16',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1650008695202_8c4727c7-912e-4814-b748-0d234eabd265.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 100000000,
#   'state': 0,
#   'title': '[24시]아이폰13 미니 13프로 맥스 (애플/삼성전기종 최고가매입)',
#   'subTitle': None,
# ...
#   'articleRegDate': '2022-04-15 02:29:50',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1649957454524_de744a2c-0eac-4ae4-b0c3-5d19faee5f5d.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 2000000,
#   'state': 0,
#   'title': '아이폰전기종(자급제,박스폰,중고폰,유심기변)매입[아이폰13프로맥스]',
#   'subTitle': None,
#   'sortDate': '2022-04-15 02:29:50',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 988,
#   'highlightedTitle': '[매입]<em>아이폰</em> <em>13</em> 프로 맥스(자급제폰,박스폰,당일개통폰,중고폰)',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910830481&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910830481,
#   'articleRegDate': '2022-04-15 02:29:35',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1649957393098_dc227a46-ca52-428c-9d34-adfe20366a74.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 3333333,
#   'state': 0,
#   'title': '[매입]아이폰 13 프로 맥스(자급제폰,박스폰,당일개통폰,중고폰)',
#   'subTitle': None,
#   'sortDate': '2022-04-15 02:29:35',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 989,
#   'highlightedTitle': '<em>아이폰</em><em>13</em> 프로맥스/프로 pro max 최고가매입(자급제,중고폰)',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910830439&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910830439,
#   'articleRegDate': '2022-04-15 02:28:47',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1649957393468_2921440a-4b96-4821-af76-0502d9b1bcb8.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 2990000,
#   'state': 0,
#   'title': '아이폰13 프로맥스/프로 pro max 최고가매입(자급제,중고폰)',
#   'subTitle': None,
#   'sortDate': '2022-04-15 02:28:47',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 990,
#   'highlightedTitle': '<em>아이폰</em><em>13</em>프로 맥스 미니 갤럭시S22 자급제 통신사 유심기변 전기종 삽니다.',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910830109&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910830109,
#   'articleRegDate': '2022-04-15 02:22:42',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1649957026819_a3a0eef5-f73e-4e1f-942b-6ae2ec20703f.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 3000,
#   'state': 0,
#   'title': '아이폰13프로 맥스 미니 갤럭시S22 자급제 통신사 유심기변 전기종 삽니다.',
#   'subTitle': None,
#   'sortDate': '2022-04-15 02:22:42',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 991,
#   'highlightedTitle': '[매입]<em>아이폰</em><em>13</em>,갤럭시S22전기종 자급제,박스폰,중고폰,파손폰매입',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=424&boardtype=C&page=1&articleid=910829993&referrerAllArticles=false',
#   'menuId': 424,
#   'articleSeq': 910829993,
#   'articleRegDate': '2022-04-15 02:20:40',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1649956904538_8168c1a6-80af-48b1-87b6-248ad0f350cd.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 2000000,
#   'state': 0,
#   'title': '[매입]아이폰13,갤럭시S22전기종 자급제,박스폰,중고폰,파손폰매입',
#   'subTitle': None,
#   'sortDate': '2022-04-15 02:20:40',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 992,
#   'highlightedTitle': '<em>아이폰</em><em>13</em>프로맥스 256기가 자급제 미개봉 판매합니다',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910829793&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910829793,
#   'articleRegDate': '2022-04-15 02:16:54',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1649956673509_8819b946-36aa-4c74-9d78-adb163784f63.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 900000,
#   'state': 0,
#   'title': '아이폰13프로맥스 256기가 자급제 미개봉 판매합니다',
#   'subTitle': None,
#   'sortDate': '2022-04-15 02:16:54',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 993,
#   'highlightedTitle': '<em>아이폰</em><em>13</em> PRO MAX 프로 맥스 자급제미개봉,당일개통,박스폰삽니다',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910829754&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910829754,
#   'articleRegDate': '2022-04-15 02:16:11',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1649956617387_c5c512be-1b93-43e8-9566-6a6d12c8387f.png?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 4999999,
#   'state': 0,
#   'title': '아이폰13 PRO MAX 프로 맥스 자급제미개봉,당일개통,박스폰삽니다',
#   'subTitle': None,
#   'sortDate': '2022-04-15 02:16:11',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 994,
#   'highlightedTitle': '[매입]<em>아이폰</em><em>13</em> 프로 맥스 애플전기종,중고폰,자급제미개봉,박스폰매입',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910829733&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910829733,
#   'articleRegDate': '2022-04-15 02:15:48',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1649956617946_0ece9deb-0049-4dc4-b48d-d6ec8949a8dc.png?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 1500000,
#   'state': 0,
#   'title': '[매입]아이폰13 프로 맥스 애플전기종,중고폰,자급제미개봉,박스폰매입',
#   'subTitle': None,
#   'sortDate': '2022-04-15 02:15:48',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 995,
#   'highlightedTitle': '<em>아이폰</em>,갤럭시(자급제,박스폰,중고폰매입)당일매입[<em>13</em>프로맥스,S22',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=424&boardtype=C&page=1&articleid=910829653&referrerAllArticles=false',
#   'menuId': 424,
#   'articleSeq': 910829653,
#   'articleRegDate': '2022-04-15 02:14:25',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1649956491304_30bf4a9d-53d9-4719-92cf-b860ec753aec.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 2000000,
#   'state': 0,
#   'title': '아이폰,갤럭시(자급제,박스폰,중고폰매입)당일매입[13프로맥스,S22',
#   'subTitle': None,
#   'sortDate': '2022-04-15 02:14:25',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 996,
#   'highlightedTitle': '<em>아이폰</em><em>13</em>프로 256기가 그라파이트 자급제 미개봉 판매 합니다',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910829589&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910829589,
#   'articleRegDate': '2022-04-15 02:13:27',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1649956433499_78acfa2d-9498-4b6b-b4ee-58e2a94b886a.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 1260000,
#   'state': 0,
#   'title': '아이폰13프로 256기가 그라파이트 자급제 미개봉 판매 합니다',
#   'subTitle': None,
#   'sortDate': '2022-04-15 02:13:27',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 997,
#   'highlightedTitle': '<em>아이폰</em><em>13</em> 12 미니 mini 11 프로맥스 자급제 매입 삽니다',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=424&boardtype=C&page=1&articleid=910829483&referrerAllArticles=false',
#   'menuId': 424,
#   'articleSeq': 910829483,
#   'articleRegDate': '2022-04-15 02:11:52',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1649956367075_8adb60d3-e467-4bee-ba3d-36b619c2f49b.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 1000000,
#   'state': 0,
#   'title': '아이폰13 12 미니 mini 11 프로맥스 자급제 매입 삽니다',
#   'subTitle': None,
#   'sortDate': '2022-04-15 02:11:52',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 998,
#   'highlightedTitle': '[매입]<em>아이폰</em> <em>13</em> 프로 맥스(자급제폰,박스폰,당일개통폰,중고폰)',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910829385&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910829385,
#   'articleRegDate': '2022-04-15 02:10:23',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1649956253037_d8005266-b22b-4105-a704-eb0b841620dd.jpeg?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 3333333,
#   'state': 0,
#   'title': '[매입]아이폰 13 프로 맥스(자급제폰,박스폰,당일개통폰,중고폰)',
#   'subTitle': None,
#   'sortDate': '2022-04-15 02:10:23',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 999,
#   'highlightedTitle': '<em>아이폰</em><em>13</em> PRO MAX 프로 맥스 자급제미개봉,당일개통,박스폰삽니다',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910829377&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910829377,
#   'articleRegDate': '2022-04-15 02:10:16',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1649956253245_d09b680f-d55b-4f13-ba4a-cc66a0984975.png?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 4999999,
#   'state': 0,
#   'title': '아이폰13 PRO MAX 프로 맥스 자급제미개봉,당일개통,박스폰삽니다',
#   'subTitle': None,
#   'sortDate': '2022-04-15 02:10:16',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  {'seq': 0,
#   'productPositionNo': 1000,
#   'highlightedTitle': '[매입]<em>아이폰</em><em>13</em> 프로 맥스 애플전기종,중고폰,자급제미개봉,박스폰매입',
#   'storeSeq': 0,
#   'platformType': 4,
#   'storeProfileUrl': 'https://img2.joongna.com/common/profile_naver_img.jpg?impolicy=thumb&size=50',
#   'storeNickname': '',
#   'userName': '',
#   'detailImgUrl': None,
#   'mainLocationName': '',
#   'locationNames': None,
#   'articleUrl': 'https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=339&boardtype=C&page=1&articleid=910829353&referrerAllArticles=false',
#   'menuId': 339,
#   'articleSeq': 910829353,
#   'articleRegDate': '2022-04-15 02:09:53',
#   'articleBadgeShow': 0,
#   'consignmentType': 0,
#   'url': '/cafe/2022/04/15/1649956253284_4f517c22-0a32-4bd2-a64b-2de1d94455f9.png?impolicy=thumb&size=150',
#   'productHiddenStatus': 0,
#   'price': 1500000,
#   'state': 0,
#   'title': '[매입]아이폰13 프로 맥스 애플전기종,중고폰,자급제미개봉,박스폰매입',
#   'subTitle': None,
#   'sortDate': '2022-04-15 02:09:53',
#   'userSeq': 0,
#   'videoUrl': '',
#   'viewCount': 0,
#   'videoProductYn': None,
#   'productType': '',
#   'ad': 0,
#   'adImpUrl': '',
#   'adClickUrl': '',
#   'adType': '',
#   'isConsignment': 0,
#   'jnPayBadgeFlag': False,
#   'intJnPayBadgeFlag': 0},
#  ...]

# %%
highlightedTitle
articleUrl
articleSeq
articleRegDate
title
sortDate
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eee3914a8eb9> in <module>
# ----> 1 title
#
# NameError: name 'title' is not defined
