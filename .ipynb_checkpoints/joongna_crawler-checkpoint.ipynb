# %%
# articleUrl
# articleSeq //불러온 첫번째 seq가 원래꺼보다 클 때
# articleRegDate
# price
# title
# sortDate
# state # 0 1 3

# %%
import pandas as pd
import json
import requests
import time
from tqdm import tqdm
# !pip install mariadb
# !pip install sqlalchemy
# !pip install pymysql
import mariadb
from sqlalchemy import create_engine
from time import strftime,localtime,time

# %% [markdown]
# 한번에 최대 10000개
#
# 3일 단위로 계속 불러오기 6개월까지

# %%
query="아이폰 13"

url = f'https://search-api.joongna.com/v25/search/product'
param = {
    "filter":{
        "dateFilterParameter":{
            "sortEndDate":"2022-05-20",
            "sortStartDate":"2022-05-14"
        },
        "flawedYn":0,
        "fullPackageYn":0,
        "limitedEditionYn":0,
#         "maxPrice":2000000000,
#         "minPrice":2,
        "tradeType":0
    },
    "productFilter":"ALL",
    "productStates":[
        0,
        1,
        99
    ],
    "searchQuantity":10000,
    "osType":2,
    "searchWord":f'{query}',
    "sort":"RECENT_SORT",
}

# %%
#json.dumps
response= requests.post(url,json=(param))
data=response.json()['data']
len(data['items'])
# Out:
# 8963

# %%
def make_binary(x):
    if x!=0:
        return 1
    return 0

col=['articleUrl',
'articleSeq',
'articleRegDate',
'price',
'title',
'state'] # 0 1 3]
# 데이터프레임 화 , 중복 제거
df=pd.DataFrame(data['items']).drop_duplicates('title')[col]
# nan 제거
df=df.dropna()
# is_sold 처리
df.rename(columns  = {'state': 'is_sold'}, inplace = True)
df['is_sold'] = df['is_sold'].map(lambda x : make_binary(x))
# seq int화
df['articleSeq']=df['articleSeq'].astype('int')
print(len(df))
# Out:
# 1022

# %%
# 매입 게시물 제거
buy = df[df['title'].str.contains('삽니|매입|사요', na=False)]
only_sale=pd.merge(df, buy, how='outer', indicator = True).query('_merge == "left_only"').drop(columns=['_merge'])
only_sale
# Out:
#                                              articleUrl  articleSeq  \
# 3     https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918247023
# 5     https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918246701
# 12    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918245407
# 15    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918244819
# 16    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918244531
# ...                                                 ...         ...
# 1017  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916942233
# 1018  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916928810
# 1019  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916922586
# 1020  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916858097
# 1021  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916852097
#
#            articleRegDate    price                                     title  \
# 3     2022-05-20 23:50:12  1250000        아이폰13프로,골드,128G,A급,배터리성능100%,광주광역시
# 5     2022-05-20 23:47:19    30000                  아이폰 13프로맥스 가죽케이스 세쿼이아그린
# 12    2022-05-20 23:36:19  1150000  아이폰13프로 128GB 시에라블루 22년5월제조 미개봉 115만팝니다.
# 15    2022-05-20 23:31:45   810000                    아이폰13미니 128기가 배터리 100%
# 16    2022-05-20 23:29:29   830000        아이폰13 128GB 스타라이트 S급 22년 2월개통 83만원
# ...                   ...      ...                                       ...
# 1017  2022-05-14 17:45:13    23000  가격내림)아이폰13 프로 맥스 pro max 정품 실리콘 케이스 블루제이
# 1018  2022-05-14 16:26:44  1350000                     아이폰13프로맥스 256 그린 새제품급
# 1019  2022-05-14 15:47:20   770000               아이폰13미니 미드나잇블랙 128gb 풀박스 새폰
# 1020  2022-05-14 10:10:51   950000                아이폰13미니 그린 256기가 미개봉제품 팝니다
# 1021  2022-05-14 09:38:30  1200000                  아이폰13프로 256기가 애플케어플러스 가입
#
#       is_sold
# 3           0
# 5           0
# 12          0
# 15          0
# 16          0
# ...       ...
# 1017        1
# 1018        1
# 1019        1
# 1020        1
# 1021        1
#
# [983 rows x 6 columns]

# %%
# 가격 25%~75% 사이만 사용
min_price=only_sale['price'].describe().loc['25%']
max_price=only_sale['price'].describe().loc['75%']
q = "(price >= @min_price) and (price <= @max_price)"
final = only_sale.query(q)
final
# Out:
#                                              articleUrl  articleSeq  \
# 3     https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918247023
# 12    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918245407
# 15    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918244819
# 16    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918244531
# 17    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918243994
# ...                                                 ...         ...
# 1015  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916969922
# 1016  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916965584
# 1019  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916922586
# 1020  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916858097
# 1021  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916852097
#
#            articleRegDate    price  \
# 3     2022-05-20 23:50:12  1250000
# 12    2022-05-20 23:36:19  1150000
# 15    2022-05-20 23:31:45   810000
# 16    2022-05-20 23:29:29   830000
# 17    2022-05-20 23:25:13  1100000
# ...                   ...      ...
# 1015  2022-05-14 20:48:47  1200000
# 1016  2022-05-14 20:21:29   750000
# 1019  2022-05-14 15:47:20   770000
# 1020  2022-05-14 10:10:51   950000
# 1021  2022-05-14 09:38:30  1200000
#
#                                            title  is_sold
# 3             아이폰13프로,골드,128G,A급,배터리성능100%,광주광역시        0
# 12      아이폰13프로 128GB 시에라블루 22년5월제조 미개봉 115만팝니다.        0
# 15                        아이폰13미니 128기가 배터리 100%        0
# 16            아이폰13 128GB 스타라이트 S급 22년 2월개통 83만원        0
# 17    [판매] ﻿아이폰13프로 그래파이트 128GB 외관 S급 공기계 [110만]        0
# ...                                          ...      ...
# 1015             아이폰 13 프로 그래파이트 256GB 자급제미개봉새상품        1
# 1016                         아이폰 13 프로 256g 급처해요        1
# 1019                 아이폰13미니 미드나잇블랙 128gb 풀박스 새폰        1
# 1020                  아이폰13미니 그린 256기가 미개봉제품 팝니다        1
# 1021                    아이폰13프로 256기가 애플케어플러스 가입        1
#
# [507 rows x 6 columns]

# %%
#is_mint
mint_list=list(final[final['title'].str.contains("s급|S급|미개봉|민트급|새상품")].index)
final['is_mint']=0
final.loc[mint_list,'is_mint']=1
final
# Out:
# <ipython-input-8-131ee4c41094>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['is_mint']=0
# C:\Users\vislab\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#                                              articleUrl  articleSeq  \
# 3     https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918247023
# 12    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918245407
# 15    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918244819
# 16    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918244531
# 17    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918243994
# ...                                                 ...         ...
# 1015  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916969922
# 1016  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916965584
# 1019  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916922586
# 1020  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916858097
# 1021  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916852097
#
#            articleRegDate    price  \
# 3     2022-05-20 23:50:12  1250000
# 12    2022-05-20 23:36:19  1150000
# 15    2022-05-20 23:31:45   810000
# 16    2022-05-20 23:29:29   830000
# 17    2022-05-20 23:25:13  1100000
# ...                   ...      ...
# 1015  2022-05-14 20:48:47  1200000
# 1016  2022-05-14 20:21:29   750000
# 1019  2022-05-14 15:47:20   770000
# 1020  2022-05-14 10:10:51   950000
# 1021  2022-05-14 09:38:30  1200000
#
#                                            title  is_sold  is_mint
# 3             아이폰13프로,골드,128G,A급,배터리성능100%,광주광역시        0        0
# 12      아이폰13프로 128GB 시에라블루 22년5월제조 미개봉 115만팝니다.        0        1
# 15                        아이폰13미니 128기가 배터리 100%        0        0
# 16            아이폰13 128GB 스타라이트 S급 22년 2월개통 83만원        0        1
# 17    [판매] ﻿아이폰13프로 그래파이트 128GB 외관 S급 공기계 [110만]        0        1
# ...                                          ...      ...      ...
# 1015             아이폰 13 프로 그래파이트 256GB 자급제미개봉새상품        1        1
# 1016                         아이폰 13 프로 256g 급처해요        1        0
# 1019                 아이폰13미니 미드나잇블랙 128gb 풀박스 새폰        1        0
# 1020                  아이폰13미니 그린 256기가 미개봉제품 팝니다        1        1
# 1021                    아이폰13프로 256기가 애플케어플러스 가입        1        0
#
# [507 rows x 7 columns]

# %%
# 지역, 이미지 처리
detail_list=[]
for seq in tqdm(final[final['is_sold']==0]['articleSeq']):
    t=time.time()
    detail_url=f'https://apis.naver.com/cafe-web/cafe-articleapi/v2/cafes/10050146/articles/{seq}'
    response=requests.get(detail_url)

    if response.status_code!=200:
        continue
    detail=response.json()
    city=detail['result']['articleRegion']['regionName1']
    state=detail['result']['articleRegion']['regionName2']
    img=detail['result']['saleInfo']['image']['url']
    detail_list.append([seq,city,state,img])

detail_df=pd.DataFrame(detail_list,columns=["articleSeq",'city','state','product_image'])
total=pd.merge(final,detail_df, how='outer',on='articleSeq')
total=total.fillna("")
total
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 473/473 [01:06<00:00,  7.12it/s]
#                                             articleUrl  articleSeq  \
# 0    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918247023
# 1    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918245407
# 2    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918244819
# 3    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918244531
# 4    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   918243994
# ..                                                 ...         ...
# 502  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916969922
# 503  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916965584
# 504  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916922586
# 505  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916858097
# 506  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916852097
#
#           articleRegDate    price                                       title  \
# 0    2022-05-20 23:50:12  1250000          아이폰13프로,골드,128G,A급,배터리성능100%,광주광역시
# 1    2022-05-20 23:36:19  1150000    아이폰13프로 128GB 시에라블루 22년5월제조 미개봉 115만팝니다.
# 2    2022-05-20 23:31:45   810000                      아이폰13미니 128기가 배터리 100%
# 3    2022-05-20 23:29:29   830000          아이폰13 128GB 스타라이트 S급 22년 2월개통 83만원
# 4    2022-05-20 23:25:13  1100000  [판매] ﻿아이폰13프로 그래파이트 128GB 외관 S급 공기계 [110만]
# ..                   ...      ...                                         ...
# 502  2022-05-14 20:48:47  1200000             아이폰 13 프로 그래파이트 256GB 자급제미개봉새상품
# 503  2022-05-14 20:21:29   750000                         아이폰 13 프로 256g 급처해요
# 504  2022-05-14 15:47:20   770000                 아이폰13미니 미드나잇블랙 128gb 풀박스 새폰
# 505  2022-05-14 10:10:51   950000                  아이폰13미니 그린 256기가 미개봉제품 팝니다
# 506  2022-05-14 09:38:30  1200000                    아이폰13프로 256기가 애플케어플러스 가입
#
#      is_sold  is_mint   city state  \
# 0          0        0
# 1          0        1
# 2          0        0  부산광역시   사상구
# 3          0        1  울산광역시    북구
# 4          0        1
# ..       ...      ...    ...   ...
# 502        1        1
# 503        1        0
# 504        1        0
# 505        1        1
# 506        1        0
#
#                                          product_image
# 0    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...
# 1
# 2    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...
# 3    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...
# 4
# ..                                                 ...
# 502
# 503
# 504
# 505
# 506
#
# [507 rows x 10 columns]

# %%
total.columns
# Out:
# Index(['articleUrl', 'articleSeq', 'articleRegDate', 'price', 'title',
#        'is_sold', 'is_mint', 'city', 'state', 'product_image'],
#       dtype='object')

# %%
# 스프링서버로부터 post의 크기 받아왔다고 가정
size=125
item_id=11
# post size에 기반한 id열 생성
total['id']=range(size+1,size+1+len(total))

# %%
#post 데이터 만들기
# item_id ,location_id , market_price_id, platform_id 바꾸는 로직 추가 필요
post_columns=['id','articleSeq','articleUrl','is_sold','is_mint','articleRegDate','title','product_image','city','state'] #platform추가
post=total[post_columns].copy()
post.rename(columns  = {
    'id' : 'post_id',
    'articleSeq' : 'pid',
    'articleSeq':'pid',
    'articleUrl':'url',
    'articleRegDate':'upload_date'
}, inplace = True)
post['item_id']=item_id
# post['location_id']=15 # 지역 데이터 앞에 꺼만 뺴오기 수원시 권선구 -> 수원시
post['platform_id']=1
post['market_price_id']=post['post_id']
post
# Out:
#      post_id        pid                                                url  \
# 0        126  918247023  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 1        127  918245407  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 2        128  918244819  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 3        129  918244531  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 4        130  918243994  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# ..       ...        ...                                                ...
# 502      628  916969922  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 503      629  916965584  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 504      630  916922586  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 505      631  916858097  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 506      632  916852097  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
#
#      is_sold  is_mint          upload_date  \
# 0          0        0  2022-05-20 23:50:12
# 1          0        1  2022-05-20 23:36:19
# 2          0        0  2022-05-20 23:31:45
# 3          0        1  2022-05-20 23:29:29
# 4          0        1  2022-05-20 23:25:13
# ..       ...      ...                  ...
# 502        1        1  2022-05-14 20:48:47
# 503        1        0  2022-05-14 20:21:29
# 504        1        0  2022-05-14 15:47:20
# 505        1        1  2022-05-14 10:10:51
# 506        1        0  2022-05-14 09:38:30
#
#                                           title  \
# 0            아이폰13프로,골드,128G,A급,배터리성능100%,광주광역시
# 1      아이폰13프로 128GB 시에라블루 22년5월제조 미개봉 115만팝니다.
# 2                        아이폰13미니 128기가 배터리 100%
# 3            아이폰13 128GB 스타라이트 S급 22년 2월개통 83만원
# 4    [판매] ﻿아이폰13프로 그래파이트 128GB 외관 S급 공기계 [110만]
# ..                                          ...
# 502             아이폰 13 프로 그래파이트 256GB 자급제미개봉새상품
# 503                         아이폰 13 프로 256g 급처해요
# 504                 아이폰13미니 미드나잇블랙 128gb 풀박스 새폰
# 505                  아이폰13미니 그린 256기가 미개봉제품 팝니다
# 506                    아이폰13프로 256기가 애플케어플러스 가입
#
#                                          product_image   city state  item_id  \
# 0    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...                    11
# 1                                                                         11
# 2    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...  부산광역시   사상구       11
# 3    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...  울산광역시    북구       11
# 4                                                                         11
# ..                                                 ...    ...   ...      ...
# 502                                                                       11
# 503                                                                       11
# 504                                                                       11
# 505                                                                       11
# 506                                                                       11
#
#      platform_id  market_price_id
# 0              1              126
# 1              1              127
# 2              1              128
# 3              1              129
# 4              1              130
# ..           ...              ...
# 502            1              628
# 503            1              629
# 504            1              630
# 505            1              631
# 506            1              632
#
# [507 rows x 13 columns]

# %%
#price
price_columns=['id','price'] #platform추가
price=total[price_columns].copy()
price.rename(columns  = {
    'id' : 'price_id',
}, inplace = True)
price['item_id']=item_id
price
# Out:
#      price_id    price  item_id
# 0         126  1250000       11
# 1         127  1150000       11
# 2         128   810000       11
# 3         129   830000       11
# 4         130  1100000       11
# ..        ...      ...      ...
# 502       628  1200000       11
# 503       629   750000       11
# 504       630   770000       11
# 505       631   950000       11
# 506       632  1200000       11
#
# [507 rows x 3 columns]

# %%
user='developer', 
password='1234', 
database='dev', 
host='3.36.254.182',
port=13306

conn  = mariadb.connect(
    user='developer', 
    password='1234', 
    database='dev', 
    host='3.36.254.182',
    port=13306
)

# 위 커넥션 정보와 동일하게 입력
engine = create_engine(f"mysql+pymysql://developer:1234@3.36.254.182:13306/dev")
engine
# Out:
# Engine(mysql+pymysql://developer:***@3.36.254.182:13306/dev)

# %%
#조회
# select_sql = "SELECT * FROM post"
# cs = conn.cursor()
# cs.execute(select_sql)
# rs = cs.fetchall()

# 이거는 스프링에서 처리하도록..?
data=(item_id,strftime('%Y-%m-%d %H:%M:%S', localtime(time())),f"{query}")

sql = """
INSERT INTO item (
    item_id,
    latest_search_time,
    name
) VALUES (
    ?, ?, ?
)
"""
cs = conn.cursor()
cs.execute(sql,data)
conn.commit()

# %%
post.drop(['city','state','platform'],axis=1,inplace=True)

# %%
t=time.time()
post.to_sql('post',engine,if_exists='append',index=False,method='multi')
price.to_sql('price',engine,if_exists='append',index=False,method='multi')
print(time.time()-t)
# Out:
# 0.24513792991638184
