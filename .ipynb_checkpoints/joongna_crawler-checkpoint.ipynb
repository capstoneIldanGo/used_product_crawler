# %%
# articleUrl
# articleSeq //불러온 첫번째 seq가 원래꺼보다 클 때
# articleRegDate
# price
# title
# sortDate
# state # 0 1 3

# %%
import pandas as pd
import json
import requests
import time
from tqdm import tqdm

# %% [markdown]
# 한번에 최대 10000개
#
# 3일 단위로 계속 불러오기 6개월까지

# %%
query="아이폰 13"

url = f'https://search-api.joongna.com/v25/search/product'
param = {
    "filter":{
        "dateFilterParameter":{
            "sortEndDate":"2022-05-19",
            "sortStartDate":"2022-05-14"
        },
        "flawedYn":0,
        "fullPackageYn":0,
        "limitedEditionYn":0,
#         "maxPrice":2000000000,
#         "minPrice":2,
        "tradeType":0
    },
    "productFilter":"ALL",
    "productStates":[
        0,
        1,
        99
    ],
    "searchQuantity":10000,
    "osType":2,
    "searchWord":f'{query}',
    "sort":"RECENT_SORT",
}

# %%
#json.dumps
response= requests.post(url,json=(param))
data=response.json()['data']
len(data['items'])
# Out:
# 7383

# %%
def make_binary(x):
    if x!=0:
        return 1
    return 0

col=['articleUrl',
'articleSeq',
'articleRegDate',
'price',
'title',
'sortDate',
'state'] # 0 1 3]
# 데이터프레임 화 , 중복 제거
df=pd.DataFrame(data['items']).drop_duplicates('title')[col]
# nan 제거
df=df.dropna()
# is_sold 처리
df.rename(columns  = {'state': 'is_sold'}, inplace = True)
df['is_sold'] = df['is_sold'].map(lambda x : make_binary(x))
# seq int화
df['articleSeq']=df['articleSeq'].astype('int')
print(len(df))
# Out:
# 834

# %%
# 매입 게시물 제거
buy = df[df['title'].str.contains('삽니|매입|사요', na=False)]
only_sale=pd.merge(df, buy, how='outer', indicator = True).query('_merge == "left_only"').drop(columns=['_merge'])
only_sale
# Out:
#                                             articleUrl  articleSeq  \
# 1    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917950787
# 10   https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917949057
# 11   https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917948845
# 12   https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917948298
# 13   https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917948066
# ..                                                 ...         ...
# 829  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916942233
# 830  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916928810
# 831  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916922586
# 832  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916858097
# 833  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916852097
#
#           articleRegDate    price                                     title  \
# 1    2022-05-19 14:48:44    28000                   아이폰 13프로 실리콘케이스 초크핑크 정품
# 10   2022-05-19 14:40:08   990000     아이폰13미니 128 256 512기가 미개봉자급제미개통새상품입니다
# 11   2022-05-19 14:39:10  1400000                아이폰13 프로맥스 256 알파인그린 판매합니다
# 12   2022-05-19 14:36:44  1370000           아이폰13 프로맥스 128 자급제 1달사용 애케플가입가능
# 13   2022-05-19 14:35:16  1690000              아이폰13 프로 1테라 미개봉자급제미개통새상품입니다
# ..                   ...      ...                                       ...
# 829  2022-05-14 17:45:13    23000  가격내림)아이폰13 프로 맥스 pro max 정품 실리콘 케이스 블루제이
# 830  2022-05-14 16:26:44  1350000                     아이폰13프로맥스 256 그린 새제품급
# 831  2022-05-14 15:47:20   770000               아이폰13미니 미드나잇블랙 128gb 풀박스 새폰
# 832  2022-05-14 10:10:51   950000                아이폰13미니 그린 256기가 미개봉제품 팝니다
# 833  2022-05-14 09:38:30  1200000                  아이폰13프로 256기가 애플케어플러스 가입
#
#                 sortDate  is_sold
# 1    2022-05-19 14:48:44        0
# 10   2022-05-19 14:40:08        0
# 11   2022-05-19 14:39:10        0
# 12   2022-05-19 14:36:44        0
# 13   2022-05-19 14:35:16        0
# ..                   ...      ...
# 829  2022-05-14 17:45:13        1
# 830  2022-05-14 16:26:44        1
# 831  2022-05-14 15:47:20        1
# 832  2022-05-14 10:10:51        1
# 833  2022-05-14 09:38:30        1
#
# [797 rows x 7 columns]

# %%
# 가격 25%~75% 사이만 사용
min_price=only_sale['price'].describe().loc['25%']
max_price=only_sale['price'].describe().loc['75%']
q = "(price >= @min_price) and (price <= @max_price)"
final = only_sale.query(q)
final
# Out:
#                                             articleUrl  articleSeq  \
# 10   https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917949057
# 18   https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917945840
# 19   https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917945755
# 21   https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917944445
# 31   https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917938083
# ..                                                 ...         ...
# 827  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916969922
# 828  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916965584
# 831  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916922586
# 832  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916858097
# 833  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916852097
#
#           articleRegDate    price  \
# 10   2022-05-19 14:40:08   990000
# 18   2022-05-19 14:22:02   949000
# 19   2022-05-19 14:21:35   990000
# 21   2022-05-19 14:15:08   845000
# 31   2022-05-19 13:42:24   130000
# ..                   ...      ...
# 827  2022-05-14 20:48:47  1200000
# 828  2022-05-14 20:21:29   750000
# 831  2022-05-14 15:47:20   770000
# 832  2022-05-14 10:10:51   950000
# 833  2022-05-14 09:38:30  1200000
#
#                                            title             sortDate  is_sold
# 10         아이폰13미니 128 256 512기가 미개봉자급제미개통새상품입니다  2022-05-19 14:40:08        0
# 18                          아이폰13 자급제 128 핑크 미개봉  2022-05-19 14:22:02        0
# 19           아이폰13 128 256 512기가 미개봉자급제미개통새상품입니다  2022-05-19 14:21:35        0
# 21             SS급]아이폰13 블랙 128G 배100 84.5만원판매해요  2022-05-19 14:15:08        0
# 31   50998 아이폰7 32기가 매트블랙 공기계 팝니다 배터리100% [13만원]  2022-05-19 13:42:24        0
# ..                                           ...                  ...      ...
# 827              아이폰 13 프로 그래파이트 256GB 자급제미개봉새상품  2022-05-14 20:48:47        1
# 828                          아이폰 13 프로 256g 급처해요  2022-05-14 20:21:29        1
# 831                  아이폰13미니 미드나잇블랙 128gb 풀박스 새폰  2022-05-14 15:47:20        1
# 832                   아이폰13미니 그린 256기가 미개봉제품 팝니다  2022-05-14 10:10:51        1
# 833                     아이폰13프로 256기가 애플케어플러스 가입  2022-05-14 09:38:30        1
#
# [415 rows x 7 columns]

# %%
#is_mint
mint_list=list(final[final['title'].str.contains("s급|S급|미개봉|민트급|새상품")].index)
final['is_mint']=0
final.loc[mint_list,'is_mint']=1
final
# Out:
# <ipython-input-147-d8c83e8b0c2e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['is_mint']=0
# C:\Users\vislab\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#                                             articleUrl  articleSeq  \
# 10   https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917949057
# 18   https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917945840
# 19   https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917945755
# 21   https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917944445
# 31   https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917938083
# ..                                                 ...         ...
# 827  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916969922
# 828  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916965584
# 831  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916922586
# 832  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916858097
# 833  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916852097
#
#           articleRegDate    price  \
# 10   2022-05-19 14:40:08   990000
# 18   2022-05-19 14:22:02   949000
# 19   2022-05-19 14:21:35   990000
# 21   2022-05-19 14:15:08   845000
# 31   2022-05-19 13:42:24   130000
# ..                   ...      ...
# 827  2022-05-14 20:48:47  1200000
# 828  2022-05-14 20:21:29   750000
# 831  2022-05-14 15:47:20   770000
# 832  2022-05-14 10:10:51   950000
# 833  2022-05-14 09:38:30  1200000
#
#                                            title             sortDate  \
# 10         아이폰13미니 128 256 512기가 미개봉자급제미개통새상품입니다  2022-05-19 14:40:08
# 18                          아이폰13 자급제 128 핑크 미개봉  2022-05-19 14:22:02
# 19           아이폰13 128 256 512기가 미개봉자급제미개통새상품입니다  2022-05-19 14:21:35
# 21             SS급]아이폰13 블랙 128G 배100 84.5만원판매해요  2022-05-19 14:15:08
# 31   50998 아이폰7 32기가 매트블랙 공기계 팝니다 배터리100% [13만원]  2022-05-19 13:42:24
# ..                                           ...                  ...
# 827              아이폰 13 프로 그래파이트 256GB 자급제미개봉새상품  2022-05-14 20:48:47
# 828                          아이폰 13 프로 256g 급처해요  2022-05-14 20:21:29
# 831                  아이폰13미니 미드나잇블랙 128gb 풀박스 새폰  2022-05-14 15:47:20
# 832                   아이폰13미니 그린 256기가 미개봉제품 팝니다  2022-05-14 10:10:51
# 833                     아이폰13프로 256기가 애플케어플러스 가입  2022-05-14 09:38:30
#
#      is_sold  is_mint
# 10         0        1
# 18         0        1
# 19         0        1
# 21         0        1
# 31         0        0
# ..       ...      ...
# 827        1        1
# 828        1        0
# 831        1        0
# 832        1        1
# 833        1        0
#
# [415 rows x 8 columns]

# %%
# 지역, 이미지 처리
detail_list=[]
for seq in tqdm(final[final['is_sold']==0]['articleSeq']):
    t=time.time()
    detail_url=f'https://apis.naver.com/cafe-web/cafe-articleapi/v2/cafes/10050146/articles/{seq}'
    response=requests.get(detail_url)

    if response.status_code!=200:
        continue
    detail=response.json()
    city=detail['result']['articleRegion']['regionName1']
    state=detail['result']['articleRegion']['regionName2']
    img=detail['result']['saleInfo']['imgUrl']
    detail_list.append([seq,city,state,img])

detail_df=pd.DataFrame(detail_list,columns=["articleSeq",'city','state','product_image'])

total=pd.merge(final,detail_df, how='outer',on='articleSeq')
total=total.fillna("")
total
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 397/397 [00:45<00:00,  8.72it/s]
#                                             articleUrl  articleSeq  \
# 0    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917949057
# 1    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917945840
# 2    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917945755
# 3    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917944445
# 4    https://m.cafe.naver.com/ArticleRead.nhn?clubi...   917938083
# ..                                                 ...         ...
# 410  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916969922
# 411  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916965584
# 412  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916922586
# 413  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916858097
# 414  https://m.cafe.naver.com/ArticleRead.nhn?clubi...   916852097
#
#           articleRegDate    price  \
# 0    2022-05-19 14:40:08   990000
# 1    2022-05-19 14:22:02   949000
# 2    2022-05-19 14:21:35   990000
# 3    2022-05-19 14:15:08   845000
# 4    2022-05-19 13:42:24   130000
# ..                   ...      ...
# 410  2022-05-14 20:48:47  1200000
# 411  2022-05-14 20:21:29   750000
# 412  2022-05-14 15:47:20   770000
# 413  2022-05-14 10:10:51   950000
# 414  2022-05-14 09:38:30  1200000
#
#                                            title             sortDate  \
# 0          아이폰13미니 128 256 512기가 미개봉자급제미개통새상품입니다  2022-05-19 14:40:08
# 1                           아이폰13 자급제 128 핑크 미개봉  2022-05-19 14:22:02
# 2            아이폰13 128 256 512기가 미개봉자급제미개통새상품입니다  2022-05-19 14:21:35
# 3              SS급]아이폰13 블랙 128G 배100 84.5만원판매해요  2022-05-19 14:15:08
# 4    50998 아이폰7 32기가 매트블랙 공기계 팝니다 배터리100% [13만원]  2022-05-19 13:42:24
# ..                                           ...                  ...
# 410              아이폰 13 프로 그래파이트 256GB 자급제미개봉새상품  2022-05-14 20:48:47
# 411                          아이폰 13 프로 256g 급처해요  2022-05-14 20:21:29
# 412                  아이폰13미니 미드나잇블랙 128gb 풀박스 새폰  2022-05-14 15:47:20
# 413                   아이폰13미니 그린 256기가 미개봉제품 팝니다  2022-05-14 10:10:51
# 414                     아이폰13프로 256기가 애플케어플러스 가입  2022-05-14 09:38:30
#
#      is_sold  is_mint   city state  \
# 0          0        1
# 1          0        1
# 2          0        1
# 3          0        1  서울특별시   관악구
# 4          0        0  부산광역시   금정구
# ..       ...      ...    ...   ...
# 410        1        1
# 411        1        0
# 412        1        0
# 413        1        1
# 414        1        0
#
#                                          product_image
# 0    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...
# 1    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...
# 2    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...
# 3    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...
# 4    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...
# ..                                                 ...
# 410
# 411
# 412
# 413
# 414
#
# [415 rows x 11 columns]

# %%
# 스프링서버로부터 post의 크기 받아왔다고 가정
size=125
item_id=11
# post size에 기반한 id열 생성
total['id']=range(size+1,size+1+len(total))

# %%
#post 데이터 만들기

# item_id ,location_id , market_price_id, platform_id 바꾸는 로직 추가 필요
post_columns=['id','articleSeq','articleUrl','is_sold','is_mint','sortDate','title','product_image','city','state'] #platform추가
post=total[post_columns].copy()
post['platform']='Jongo Nara'
post.rename(columns  = {
    'id' : 'post_id',
    'articleSeq' : 'pid',
    'state': 'is_sold',
    'articleSeq':'pid',
    'articleUrl':'url',
    'sortDate':'upload_date'
}, inplace = True)
post['item_id']=item_id
post['location_id']=15
post['platform_id']=14
post['marker_price_id']=29
post
# Out:
#      post_id        pid                                                url  \
# 0        126  917949057  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 1        127  917945840  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 2        128  917945755  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 3        129  917944445  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 4        130  917938083  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# ..       ...        ...                                                ...
# 410      536  916969922  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 411      537  916965584  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 412      538  916922586  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 413      539  916858097  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
# 414      540  916852097  https://m.cafe.naver.com/ArticleRead.nhn?clubi...
#
#     is_sold  is_mint          upload_date  \
# 0         0        1  2022-05-19 14:40:08
# 1         0        1  2022-05-19 14:22:02
# 2         0        1  2022-05-19 14:21:35
# 3         0        1  2022-05-19 14:15:08
# 4         0        0  2022-05-19 13:42:24
# ..      ...      ...                  ...
# 410       1        1  2022-05-14 20:48:47
# 411       1        0  2022-05-14 20:21:29
# 412       1        0  2022-05-14 15:47:20
# 413       1        1  2022-05-14 10:10:51
# 414       1        0  2022-05-14 09:38:30
#
#                                            title  \
# 0          아이폰13미니 128 256 512기가 미개봉자급제미개통새상품입니다
# 1                           아이폰13 자급제 128 핑크 미개봉
# 2            아이폰13 128 256 512기가 미개봉자급제미개통새상품입니다
# 3              SS급]아이폰13 블랙 128G 배100 84.5만원판매해요
# 4    50998 아이폰7 32기가 매트블랙 공기계 팝니다 배터리100% [13만원]
# ..                                           ...
# 410              아이폰 13 프로 그래파이트 256GB 자급제미개봉새상품
# 411                          아이폰 13 프로 256g 급처해요
# 412                  아이폰13미니 미드나잇블랙 128gb 풀박스 새폰
# 413                   아이폰13미니 그린 256기가 미개봉제품 팝니다
# 414                     아이폰13프로 256기가 애플케어플러스 가입
#
#                                          product_image   city is_sold  \
# 0    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...
# 1    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...
# 2    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...
# 3    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...  서울특별시     관악구
# 4    https://cafeptthumb-phinf.pstatic.net/MjAyMjA1...  부산광역시     금정구
# ..                                                 ...    ...     ...
# 410
# 411
# 412
# 413
# 414
#
#        platform  item_id  location_id  platform_id  marker_price_id
# 0    Jongo Nara       11           15           14               29
# 1    Jongo Nara       11           15           14               29
# 2    Jongo Nara       11           15           14               29
# 3    Jongo Nara       11           15           14               29
# 4    Jongo Nara       11           15           14               29
# ..          ...      ...          ...          ...              ...
# 410  Jongo Nara       11           15           14               29
# 411  Jongo Nara       11           15           14               29
# 412  Jongo Nara       11           15           14               29
# 413  Jongo Nara       11           15           14               29
# 414  Jongo Nara       11           15           14               29
#
# [415 rows x 15 columns]

# %%
# !pip install mariadb
# !pip install sqlalchemy
# !pip install pymysql
import mariadb
from sqlalchemy import create_engine
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2

# %%
user='developer', 
password='1234', 
database='dev', 
host='3.36.254.182',
port=13306

# conn  = mariadb.connect(
#     user='developer', 
#     password='1234', 
#     database='dev', 
#     host='3.36.254.182',
#     port=13306
# )

# 위 커넥션 정보와 동일하게 입력
engine = create_engine(f"mysql+pymysql://developer:1234@3.36.254.182:13306/dev")

# %%
#조회
# select_sql = "SELECT * FROM post"
# cs = conn.cursor()
# cs.execute(select_sql)
# rs = cs.fetchall()

# 이거는 스프링에서 처리하도록..?
data=(12,None,"aaa 13")

sql = """
INSERT INTO item (
    item_id,
    latest_search_time,
    name
) VALUES (
    ?, ?, ?
)
"""
cs = conn.cursor()
cs.execute(sql,data)
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-208-7796c28024f0> in <module>
#      18 """
#      19 cs = conn.cursor()
# ---> 20 cs.execute(sql,data)
#      21 conn.commit()
#
# IntegrityError: Duplicate entry '12' for key 'PRIMARY'

# %%
t=time.time()
post.to_sql('post',engine,if_exists='replace',index=False,method='multi')
print(time.time()-t)

# %%
select_sql = "SELECT * FROM post"
cs = conn.cursor()
cs.execute(select_sql)
rs = cs.fetchall()
rs
# 이거는 스프링에서 처리하도록..?
# Out:
# [(40,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   '삼성노트북9',
#   datetime.datetime(2022, 5, 17, 9, 16, 56, 298513),
#   'https://m.joongna.com/product-detail/44356854?transactionId=1652367861311_-2316380558694945254&abTestType=null&productPositionNo=6',
#   4,
#   15,
#   28,
#   11),
#  (41,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   '삼성 갤럭시북s 초경량 터치스크린 노트북 삼성노트북 i5 256기가',
#   datetime.datetime(2022, 5, 19, 9, 16, 56, 298558),
#   'https://www.daangn.com/articles/394132410',
#   4,
#   16,
#   29,
#   12),
#  (42,
#   b'\x01',
#   b'\x01',
#   None,
#   'image1',
#   '임영웅 대전 Vip, S석 팜',
#   datetime.datetime(2022, 4, 16, 9, 16, 56, 298567),
#   'https://m.bunjang.co.kr/products/187681288',
#   6,
#   17,
#   31,
#   14),
#  (43,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   '윈도우11 i3 삼성노트북 램8 SSD256기가',
#   datetime.datetime(2022, 5, 8, 9, 16, 56, 298584),
#   'https://www.hellomarket.com/item/173203797?viewPath=search_list&clickPath=search&feedPosition=35',
#   4,
#   15,
#   30,
#   13),
#  (44,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   '삼성노트북 sens R530노트북 팜니다',
#   datetime.datetime(2022, 5, 14, 9, 16, 56, 298592),
#   'https://www.daangn.com/articles/403125457',
#   4,
#   18,
#   36,
#   12),
#  (45,
#   b'\x01',
#   b'\x01',
#   None,
#   'image1',
#   '♡개인♡램8G♡슬림제품♡삼성 화이트 노트북♡',
#   datetime.datetime(2022, 2, 15, 9, 16, 56, 298600),
#   'https://m.joongna.com/product-detail/42666914?transactionId=1652367861311_-2316380558694945254&abTestType=null&productPositionNo=7',
#   4,
#   19,
#   30,
#   11),
#  (46,
#   b'\x01',
#   b'\x00',
#   None,
#   'image1',
#   '삼성 고사양 슬림형 경량 노트북 팔아요 ~ 부산',
#   datetime.datetime(2022, 3, 8, 9, 16, 56, 298608),
#   'https://m.joongna.com/product-detail/44344068?transactionId=1652367861311_-2316380558694945254&abTestType=null&productPositionNo=8',
#   4,
#   17,
#   31,
#   11),
#  (47,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   '삼성 노트북 Odyssey NT800G5H-X716A GTX1060 + 2Tera i7 게이밍 노트북 팝니다',
#   datetime.datetime(2022, 3, 30, 9, 16, 56, 298614),
#   'https://www.daangn.com/articles/403019686',
#   4,
#   20,
#   36,
#   12),
#  (48,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   '아이패드 에어4 wifi 64GB 미개봉 스그 팝니다',
#   datetime.datetime(2022, 4, 29, 9, 16, 56, 298621),
#   'https://m.joongna.com/product-detail/44393254?transactionId=1652369237734_-8104792347058203000&abTestType=null&productPositionNo=1',
#   5,
#   15,
#   30,
#   11),
#  (49,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   '삼성노트북 s910s5k 15인치 노트북 팝니다.',
#   datetime.datetime(2022, 5, 19, 9, 16, 56, 298628),
#   'https://www.daangn.com/articles/400580957',
#   4,
#   16,
#   37,
#   12),
#  (50,
#   b'\x01',
#   b'\x01',
#   None,
#   'image1',
#   '산리오 서프라이즈 마이 키링 양도',
#   datetime.datetime(2022, 4, 16, 9, 16, 56, 298641),
#   'https://m.bunjang.co.kr/products/187683058',
#   6,
#   17,
#   30,
#   14),
#  (51,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   '윈도우11 i5 삼성노트북',
#   datetime.datetime(2022, 1, 29, 9, 16, 56, 298650),
#   'https://www.hellomarket.com/item/173491648?viewPath=search_list&clickPath=search&feedPosition=36',
#   4,
#   15,
#   32,
#   13),
#  (52,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   '에어팟 프로 ( Air pods pro )',
#   datetime.datetime(2022, 5, 14, 9, 16, 56, 298656),
#   'https://www.daangn.com/articles/401695283',
#   6,
#   18,
#   33,
#   12),
#  (53,
#   b'\x01',
#   b'\x01',
#   None,
#   'image1',
#   '아이패드프로5세대 11 미개봉 새상품',
#   datetime.datetime(2022, 4, 7, 9, 16, 56, 298663),
#   'https://m.joongna.com/product-detail/44215829?transactionId=1652369237734_-8104792347058203000&abTestType=null&productPositionNo=3',
#   5,
#   19,
#   35,
#   11),
#  (54,
#   b'\x01',
#   b'\x00',
#   None,
#   'image1',
#   '졸업사진 개화기 의상 판매',
#   datetime.datetime(2022, 4, 27, 9, 16, 56, 298670),
#   'https://m.bunjang.co.kr/products/187682022',
#   4,
#   17,
#   36,
#   14),
#  (55,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   'Air Pods Pro',
#   datetime.datetime(2022, 3, 30, 9, 16, 56, 298675),
#   'https://www.daangn.com/articles/402821862',
#   6,
#   20,
#   38,
#   12),
#  (56,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   '아이패드 에어3 wifi 64g + 애플펜슬 1세대',
#   datetime.datetime(2022, 4, 20, 9, 16, 56, 298681),
#   'https://m.joongna.com/product-detail/44355468?transactionId=1652369237734_-8104792347058203000&abTestType=null&productPositionNo=10',
#   5,
#   15,
#   32,
#   11),
#  (57,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   '에어팟 프로 / air pods pro 팝니다',
#   datetime.datetime(2022, 5, 19, 9, 16, 56, 298687),
#   'https://www.daangn.com/articles/400004645',
#   6,
#   16,
#   28,
#   12),
#  (58,
#   b'\x01',
#   b'\x01',
#   None,
#   'image1',
#   '콘스탄틴 디스페랄 2017',
#   datetime.datetime(2022, 4, 16, 9, 16, 56, 298694),
#   'https://m.bunjang.co.kr/products/187508220',
#   6,
#   17,
#   29,
#   14),
#  (59,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   '갤럭시 버즈2 (미개봉 새상품)',
#   datetime.datetime(2022, 3, 29, 9, 16, 56, 298700),
#   'https://m.bunjang.co.kr/products/187646229?q=%EB%B2%84%EC%A6%88&ref=%EA%B2%80%EC%83%89%EA%B2%B0%EA%B3%BC',
#   10,
#   15,
#   28,
#   14),
#  (60,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   'air pods3 에어팟3세대 정품. 거의 새상품',
#   datetime.datetime(2022, 5, 14, 9, 16, 56, 298707),
#   'https://www.daangn.com/articles/399500440',
#   6,
#   18,
#   39,
#   12),
#  (61,
#   b'\x01',
#   b'\x01',
#   None,
#   'image1',
#   '졸업사진 컨셉 해적 코스프레 의상 대여',
#   datetime.datetime(2022, 2, 18, 9, 16, 56, 298714),
#   'https://m.bunjang.co.kr/products/168582055',
#   1,
#   19,
#   39,
#   14),
#  (62,
#   b'\x01',
#   b'\x00',
#   None,
#   'image1',
#   '21년식 lg 그램 팝니다(박스는 없어요)',
#   datetime.datetime(2022, 4, 27, 9, 16, 56, 298720),
#   'https://m.joongna.com/product-detail/44379751?transactionId=1652369407197_4707925103118368500&abTestType=null&productPositionNo=1',
#   8,
#   17,
#   34,
#   11),
#  (63,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   '삼성 TV 43인치 팝니다. 티비 텔레비전',
#   datetime.datetime(2022, 3, 30, 9, 16, 56, 298727),
#   'https://www.daangn.com/articles/402963114',
#   7,
#   20,
#   28,
#   12),
#  (64,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   'LG그램 15인치 노트북',
#   datetime.datetime(2022, 5, 7, 9, 16, 56, 298733),
#   'https://m.joongna.com/product-detail/44134166?transactionId=1652369407197_4707925103118368500&abTestType=null&productPositionNo=3',
#   8,
#   15,
#   32,
#   11),
#  (65,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   '32인치 삼성 led티비 텔레비전 삼성TV',
#   datetime.datetime(2022, 5, 19, 9, 16, 56, 298739),
#   'https://www.daangn.com/articles/401726366',
#   7,
#   16,
#   37,
#   12),
#  (66,
#   b'\x01',
#   b'\x01',
#   None,
#   'image1',
#   '앙스타장터 로제트 이타백 판매 양도 시광뱃지 이베코레',
#   datetime.datetime(2022, 4, 16, 9, 16, 56, 298745),
#   'https://m.bunjang.co.kr/products/187684271',
#   6,
#   17,
#   29,
#   14),
#  (67,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   '버즈 라이브 블랙 미개봉 새상품 판매',
#   datetime.datetime(2022, 5, 2, 9, 16, 56, 298751),
#   'https://m.bunjang.co.kr/products/187430587?q=%EB%B2%84%EC%A6%88&ref=%EA%B2%80%EC%83%89%EA%B2%B0%EA%B3%BC',
#   10,
#   15,
#   34,
#   14),
#  (68,
#   b'\x00',
#   b'\x00',
#   None,
#   'image1',
#   'TV, 티비, 텔레비전, 삼성 티비',
#   datetime.datetime(2022, 5, 14, 9, 16, 56, 298757),
#   'https://www.daangn.com/articles/403264880',
#   7,
#   18,
#   38,
#   12),
#  (69,
#   b'\x01',
#   b'\x01',
#   None,
#   'image1',
#   '엔진11 크릿디 블러드오렌지 개급처',
#   datetime.datetime(2022, 2, 18, 9, 16, 56, 298763),
#   'https://m.bunjang.co.kr/products/186383190',
#   1,
#   19,
#   35,
#   14),
#  (70,
#   b'\x01',
#   b'\x00',
#   None,
#   'image1',
#   'lg그램 15인치 15ZD90N-VX70K',
#   datetime.datetime(2022, 4, 24, 9, 16, 56, 298769),
#   'https://m.joongna.com/product-detail/42981732?transactionId=1652369407197_4707925103118368500&abTestType=null&productPositionNo=4',
#   8,
#   17,
#   29,
#   11)]

# %%
engine
# Out:
# Engine(mysql+pymysql://('developer',):***@('3.36.254.182',):13306/('dev',))

# %%
sql = """
INSERT INTO post (
    item_id,
    latest_search_time,
    name
) VALUES (
    ?, ?, ?
)
"""
cs = conn.cursor()
cs.execute(sql,data)
conn.commit()
