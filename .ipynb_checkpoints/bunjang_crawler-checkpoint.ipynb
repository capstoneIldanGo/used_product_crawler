# %% [markdown]
# update_time 으로 끊기
#
# pid uid는 시간이랑 상관이없다,,
#
# 앱 상에서 데이터 가져오는거는 2차데이터 필요없음
#
# location, name, pid , price , product_image, tag, updatetime , status

# %%
import requests
import json
import pandas as pd
from datetime import datetime
from time import strftime,localtime,time
import mariadb
from sqlalchemy import create_engine
from tqdm import tqdm
def bunjang(key_word, pages):
    pid = []
    for page in range(pages):
        url = f'https://api.bunjang.co.kr/api/1/find_v2.json?order=date&n=200&page={page}&req_ref=search&q={key_word}&stat_device=w&stat_category_required=1&version=4'
        response = requests.get(url)
        datas = response.json()['list']
        ids = [data['pid'] for data in datas]
        pid.extend(ids)
        items=[]
        for id in pid:
            url = f'https://api.bunjang.co.kr/api/1/product/{id}/detail_info.json?version=4'
            response = requests.get(url)
            try:
                details = response.json()['item_info']
                details.pop('category_name')
                details.pop('pay_option')
                items.append(details)
            except:
                print('error')
        df = pd.DataFrame(items)
        bunjang_df = df[['name','price','location','description_for_detail','num_item_view','pid']]
        bunjang_df['url'] = 'https://m.bunjang.co.kr/products/'+ bunjang_df['pid']
        bunjang_df['market'] = '번개장터'
        bunjang_df['keyword'] = key_word
#         bunjang_df.drop(['pid'], axis=1)
        
        return bunjang_df
    
    
def make_binary(x):
    if x!=0:
        return 1
    return 0
def make_local_str_time(x):
    return strftime('%Y-%m-%d %H:%M:%S', localtime(x))

# %%
categories = ["자전거"]
a=[]
for category in categories:
    a.append(bunjang(category,5))
# Out:
# <ipython-input-1-f3f37218ba97>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bunjang_df['url'] = 'https://m.bunjang.co.kr/products/'+ bunjang_df['pid']
# <ipython-input-1-f3f37218ba97>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bunjang_df['market'] = '번개장터'
# <ipython-input-1-f3f37218ba97>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bunjang_df['keyword'] = key_word

# %%
page=0
key_word="커피 믹스"
url = f'https://api.bunjang.co.kr/api/1/find_v2.json?order=date&n=200&page={page}&req_ref=search&q={key_word}&stat_device=w&stat_category_required=1&version=4'
data = requests.get(url).json()['list']
df=pd.DataFrame(data)

# %%
#
col =['pid','update_time','price', 'name','status', 'location', 'product_image']
total=df[col]
total['status'] = total['status'].map(lambda x : make_binary(x))
total['url'] = 'https://m.bunjang.co.kr/products/'+ total['pid']
total['update_time']=total['update_time'].map(lambda x : make_local_str_time(x))
total=total.dropna()
total
# Out:
# <ipython-input-4-9e5a12ddd1cb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total['status'] = total['status'].map(lambda x : make_binary(x))
# <ipython-input-4-9e5a12ddd1cb>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total['url'] = 'https://m.bunjang.co.kr/products/'+ total['pid']
# <ipython-input-4-9e5a12ddd1cb>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total['update_time']=total['update_time'].map(lambda x : make_local_str_time(x))
#            pid          update_time  price  \
# 0    188421407  2022-05-25 04:29:53  30000
# 1    188824163  2022-05-25 03:51:12  15510
# 2    188332247  2022-05-25 02:49:44  62000
# 3    184409539  2022-05-25 01:08:26  12500
# 4    180721599  2022-05-25 01:08:26  38500
# ..         ...                  ...    ...
# 195  177958131  2022-02-04 09:54:28  12000
# 196  168492640  2022-02-03 03:05:22   8000
# 197  177768592  2022-02-02 11:51:17  58000
# 198  177702186  2022-02-01 02:18:33  11000
# 199  177603701  2022-02-01 02:12:20  33000
#
#                                          name  status          location  \
# 0    맥심 커피 믹스 100개+맥심 모카골드 마일드 75개+신라면 낱개 15개       1      충청북도 진천군 진천읍
# 1                     맥심 모카골드 마일드 커피믹스 160스틱        1
# 2       800개 (무료배송) 프렌치카페 800개 커피믹스 싸고 맛있는 커피       1
# 3           [맥심]오리지날or오리지날or화이트골드,화이트 믹스커피입니다       1  경기도 성남시 분당구 서현1동
# 4        믹스커피 180+180 모카골드 화이트골드 360T미개봉~새상품~       1   경기도 성남시 분당구 삼평동
# ..                                        ...     ...               ...
# 195                                   이디야커피믹스       1
# 196                               맥심 아이스커피 믹스       1
# 197         맥스웰하우스 자판기용 커피믹스 마일드 900gX12개 1박스       1    대구광역시 달서구 이곡1동
# 198                         커피믹스100믹스 종이컵100개       1      경상남도 양산시 평산동
# 199                        커피믹스 300믹스 종이컵300개       1      경상남도 양산시 평산동
#
#                                          product_image  \
# 0    https://media.bunjang.co.kr/product/188421407_...
# 1    https://media.bunjang.co.kr/product/188824163_...
# 2    https://media.bunjang.co.kr/product/188332247_...
# 3    https://media.bunjang.co.kr/product/184409539_...
# 4    https://media.bunjang.co.kr/product/180721599_...
# ..                                                 ...
# 195  https://media.bunjang.co.kr/product/177958131_...
# 196  https://media.bunjang.co.kr/product/168492640_...
# 197  https://media.bunjang.co.kr/product/177768592_...
# 198  https://media.bunjang.co.kr/product/177702186_...
# 199  https://media.bunjang.co.kr/product/177603701_...
#
#                                             url
# 0    https://m.bunjang.co.kr/products/188421407
# 1    https://m.bunjang.co.kr/products/188824163
# 2    https://m.bunjang.co.kr/products/188332247
# 3    https://m.bunjang.co.kr/products/184409539
# 4    https://m.bunjang.co.kr/products/180721599
# ..                                          ...
# 195  https://m.bunjang.co.kr/products/177958131
# 196  https://m.bunjang.co.kr/products/168492640
# 197  https://m.bunjang.co.kr/products/177768592
# 198  https://m.bunjang.co.kr/products/177702186
# 199  https://m.bunjang.co.kr/products/177603701
#
# [200 rows x 8 columns]

# %%
buy = total[total['name'].str.contains('삽니|매입|사요', na=False)]
only_sale=pd.merge(total, buy, how='outer', indicator = True).query('_merge == "left_only"').drop(columns=['_merge'])
only_sale
# Out:
#            pid          update_time  price  \
# 0    188421407  2022-05-25 04:29:53  30000
# 1    188824163  2022-05-25 03:51:12  15510
# 2    188332247  2022-05-25 02:49:44  62000
# 3    184409539  2022-05-25 01:08:26  12500
# 4    180721599  2022-05-25 01:08:26  38500
# ..         ...                  ...    ...
# 195  177958131  2022-02-04 09:54:28  12000
# 196  168492640  2022-02-03 03:05:22   8000
# 197  177768592  2022-02-02 11:51:17  58000
# 198  177702186  2022-02-01 02:18:33  11000
# 199  177603701  2022-02-01 02:12:20  33000
#
#                                          name  status          location  \
# 0    맥심 커피 믹스 100개+맥심 모카골드 마일드 75개+신라면 낱개 15개       1      충청북도 진천군 진천읍
# 1                     맥심 모카골드 마일드 커피믹스 160스틱        1
# 2       800개 (무료배송) 프렌치카페 800개 커피믹스 싸고 맛있는 커피       1
# 3           [맥심]오리지날or오리지날or화이트골드,화이트 믹스커피입니다       1  경기도 성남시 분당구 서현1동
# 4        믹스커피 180+180 모카골드 화이트골드 360T미개봉~새상품~       1   경기도 성남시 분당구 삼평동
# ..                                        ...     ...               ...
# 195                                   이디야커피믹스       1
# 196                               맥심 아이스커피 믹스       1
# 197         맥스웰하우스 자판기용 커피믹스 마일드 900gX12개 1박스       1    대구광역시 달서구 이곡1동
# 198                         커피믹스100믹스 종이컵100개       1      경상남도 양산시 평산동
# 199                        커피믹스 300믹스 종이컵300개       1      경상남도 양산시 평산동
#
#                                          product_image  \
# 0    https://media.bunjang.co.kr/product/188421407_...
# 1    https://media.bunjang.co.kr/product/188824163_...
# 2    https://media.bunjang.co.kr/product/188332247_...
# 3    https://media.bunjang.co.kr/product/184409539_...
# 4    https://media.bunjang.co.kr/product/180721599_...
# ..                                                 ...
# 195  https://media.bunjang.co.kr/product/177958131_...
# 196  https://media.bunjang.co.kr/product/168492640_...
# 197  https://media.bunjang.co.kr/product/177768592_...
# 198  https://media.bunjang.co.kr/product/177702186_...
# 199  https://media.bunjang.co.kr/product/177603701_...
#
#                                             url
# 0    https://m.bunjang.co.kr/products/188421407
# 1    https://m.bunjang.co.kr/products/188824163
# 2    https://m.bunjang.co.kr/products/188332247
# 3    https://m.bunjang.co.kr/products/184409539
# 4    https://m.bunjang.co.kr/products/180721599
# ..                                          ...
# 195  https://m.bunjang.co.kr/products/177958131
# 196  https://m.bunjang.co.kr/products/168492640
# 197  https://m.bunjang.co.kr/products/177768592
# 198  https://m.bunjang.co.kr/products/177702186
# 199  https://m.bunjang.co.kr/products/177603701
#
# [200 rows x 8 columns]

# %%
# # 가격 25%~75% 사이만 사용
only_sale['price']=only_sale['price'].astype("int")
min_price=only_sale['price'].describe().loc['25%']
max_price=only_sale['price'].describe().loc['75%']
q = "(price >= @min_price) and (price <= @max_price)"
final = only_sale.query(q)
final
# Out:
#            pid          update_time  price  \
# 0    188421407  2022-05-25 04:29:53  30000
# 1    188824163  2022-05-25 03:51:12  15510
# 4    180721599  2022-05-25 01:08:26  38500
# 5    179149750  2022-05-25 12:33:13  20000
# 6    187808246  2022-05-25 12:23:35  20000
# ..         ...                  ...    ...
# 189  161193954  2022-02-14 07:30:07  26000
# 191  168865132  2022-02-13 08:41:02  25000
# 192  178358894  2022-02-10 02:45:59  29000
# 194   97375194  2022-02-06 04:54:31  24000
# 199  177603701  2022-02-01 02:12:20  33000
#
#                                          name  status           location  \
# 0    맥심 커피 믹스 100개+맥심 모카골드 마일드 75개+신라면 낱개 15개       1       충청북도 진천군 진천읍
# 1                     맥심 모카골드 마일드 커피믹스 160스틱        1
# 4        믹스커피 180+180 모카골드 화이트골드 360T미개봉~새상품~       1    경기도 성남시 분당구 삼평동
# 5                          맥심 슈프림골드 커피믹스 170T       1  충청북도 청주시 청원구 내덕2동
# 6                             맥심모카골드커피믹스 180T       1     대구광역시 달서구 상인2동
# ..                                        ...     ...                ...
# 189                프렌치커피 믹스 총 340T (170t x 2)       1
# 191                  커피믹스100믹스 생강차50믹스 종이컵50개       1       경상남도 양산시 평산동
# 192          (무배) 프렌치카페 커피믹스 400T (50T X 8ea)       1
# 194                            프렌치카페 커피믹스300개       1
# 199                        커피믹스 300믹스 종이컵300개       1       경상남도 양산시 평산동
#
#                                          product_image  \
# 0    https://media.bunjang.co.kr/product/188421407_...
# 1    https://media.bunjang.co.kr/product/188824163_...
# 4    https://media.bunjang.co.kr/product/180721599_...
# 5    https://media.bunjang.co.kr/product/179149750_...
# 6    https://media.bunjang.co.kr/product/187808246_...
# ..                                                 ...
# 189  https://media.bunjang.co.kr/product/161193954_...
# 191  https://media.bunjang.co.kr/product/168865132_...
# 192  https://media.bunjang.co.kr/product/178358894_...
# 194  https://media.bunjang.co.kr/product/97375194_1...
# 199  https://media.bunjang.co.kr/product/177603701_...
#
#                                             url
# 0    https://m.bunjang.co.kr/products/188421407
# 1    https://m.bunjang.co.kr/products/188824163
# 4    https://m.bunjang.co.kr/products/180721599
# 5    https://m.bunjang.co.kr/products/179149750
# 6    https://m.bunjang.co.kr/products/187808246
# ..                                          ...
# 189  https://m.bunjang.co.kr/products/161193954
# 191  https://m.bunjang.co.kr/products/168865132
# 192  https://m.bunjang.co.kr/products/178358894
# 194   https://m.bunjang.co.kr/products/97375194
# 199  https://m.bunjang.co.kr/products/177603701
#
# [101 rows x 8 columns]

# %%
#is_mint
mint_list=list(final[final['name'].str.contains("s급|S급|미개봉|민트급|새상품")].index)
final['is_mint']=0
final.loc[mint_list,'is_mint']=1
final
# Out:
# <ipython-input-10-d5d00417f8f1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['is_mint']=0
# C:\Users\vislab\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#            pid          update_time  price  \
# 0    188421407  2022-05-25 04:29:53  30000
# 1    188824163  2022-05-25 03:51:12  15510
# 4    180721599  2022-05-25 01:08:26  38500
# 5    179149750  2022-05-25 12:33:13  20000
# 6    187808246  2022-05-25 12:23:35  20000
# ..         ...                  ...    ...
# 189  161193954  2022-02-14 07:30:07  26000
# 191  168865132  2022-02-13 08:41:02  25000
# 192  178358894  2022-02-10 02:45:59  29000
# 194   97375194  2022-02-06 04:54:31  24000
# 199  177603701  2022-02-01 02:12:20  33000
#
#                                          name  status           location  \
# 0    맥심 커피 믹스 100개+맥심 모카골드 마일드 75개+신라면 낱개 15개       1       충청북도 진천군 진천읍
# 1                     맥심 모카골드 마일드 커피믹스 160스틱        1
# 4        믹스커피 180+180 모카골드 화이트골드 360T미개봉~새상품~       1    경기도 성남시 분당구 삼평동
# 5                          맥심 슈프림골드 커피믹스 170T       1  충청북도 청주시 청원구 내덕2동
# 6                             맥심모카골드커피믹스 180T       1     대구광역시 달서구 상인2동
# ..                                        ...     ...                ...
# 189                프렌치커피 믹스 총 340T (170t x 2)       1
# 191                  커피믹스100믹스 생강차50믹스 종이컵50개       1       경상남도 양산시 평산동
# 192          (무배) 프렌치카페 커피믹스 400T (50T X 8ea)       1
# 194                            프렌치카페 커피믹스300개       1
# 199                        커피믹스 300믹스 종이컵300개       1       경상남도 양산시 평산동
#
#                                          product_image  \
# 0    https://media.bunjang.co.kr/product/188421407_...
# 1    https://media.bunjang.co.kr/product/188824163_...
# 4    https://media.bunjang.co.kr/product/180721599_...
# 5    https://media.bunjang.co.kr/product/179149750_...
# 6    https://media.bunjang.co.kr/product/187808246_...
# ..                                                 ...
# 189  https://media.bunjang.co.kr/product/161193954_...
# 191  https://media.bunjang.co.kr/product/168865132_...
# 192  https://media.bunjang.co.kr/product/178358894_...
# 194  https://media.bunjang.co.kr/product/97375194_1...
# 199  https://media.bunjang.co.kr/product/177603701_...
#
#                                             url  is_mint
# 0    https://m.bunjang.co.kr/products/188421407        0
# 1    https://m.bunjang.co.kr/products/188824163        0
# 4    https://m.bunjang.co.kr/products/180721599        1
# 5    https://m.bunjang.co.kr/products/179149750        0
# 6    https://m.bunjang.co.kr/products/187808246        0
# ..                                          ...      ...
# 189  https://m.bunjang.co.kr/products/161193954        0
# 191  https://m.bunjang.co.kr/products/168865132        0
# 192  https://m.bunjang.co.kr/products/178358894        0
# 194   https://m.bunjang.co.kr/products/97375194        0
# 199  https://m.bunjang.co.kr/products/177603701        0
#
# [101 rows x 9 columns]

# %%
def return_city(x):
    if len(x)>0:
        return x[0]
    return ""
def return_state(x):
    if len(x)>1:
        return x[1]
    return ""

# %%
final['city']=final['location'].str.split().map(lambda x: return_city(x))
final['state']=final['location'].str.split().map(lambda x: return_state(x))
# Out:
# <ipython-input-21-01c97052249d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['city']=final['location'].str.split().map(lambda x: return_city(x))
# <ipython-input-21-01c97052249d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['state']=final['location'].str.split().map(lambda x: return_state(x))

# %%
final
# Out:
#            pid          update_time  price  \
# 0    188421407  2022-05-25 04:29:53  30000
# 1    188824163  2022-05-25 03:51:12  15510
# 4    180721599  2022-05-25 01:08:26  38500
# 5    179149750  2022-05-25 12:33:13  20000
# 6    187808246  2022-05-25 12:23:35  20000
# ..         ...                  ...    ...
# 189  161193954  2022-02-14 07:30:07  26000
# 191  168865132  2022-02-13 08:41:02  25000
# 192  178358894  2022-02-10 02:45:59  29000
# 194   97375194  2022-02-06 04:54:31  24000
# 199  177603701  2022-02-01 02:12:20  33000
#
#                                          name  status           location  \
# 0    맥심 커피 믹스 100개+맥심 모카골드 마일드 75개+신라면 낱개 15개       1       충청북도 진천군 진천읍
# 1                     맥심 모카골드 마일드 커피믹스 160스틱        1
# 4        믹스커피 180+180 모카골드 화이트골드 360T미개봉~새상품~       1    경기도 성남시 분당구 삼평동
# 5                          맥심 슈프림골드 커피믹스 170T       1  충청북도 청주시 청원구 내덕2동
# 6                             맥심모카골드커피믹스 180T       1     대구광역시 달서구 상인2동
# ..                                        ...     ...                ...
# 189                프렌치커피 믹스 총 340T (170t x 2)       1
# 191                  커피믹스100믹스 생강차50믹스 종이컵50개       1       경상남도 양산시 평산동
# 192          (무배) 프렌치카페 커피믹스 400T (50T X 8ea)       1
# 194                            프렌치카페 커피믹스300개       1
# 199                        커피믹스 300믹스 종이컵300개       1       경상남도 양산시 평산동
#
#                                          product_image  \
# 0    https://media.bunjang.co.kr/product/188421407_...
# 1    https://media.bunjang.co.kr/product/188824163_...
# 4    https://media.bunjang.co.kr/product/180721599_...
# 5    https://media.bunjang.co.kr/product/179149750_...
# 6    https://media.bunjang.co.kr/product/187808246_...
# ..                                                 ...
# 189  https://media.bunjang.co.kr/product/161193954_...
# 191  https://media.bunjang.co.kr/product/168865132_...
# 192  https://media.bunjang.co.kr/product/178358894_...
# 194  https://media.bunjang.co.kr/product/97375194_1...
# 199  https://media.bunjang.co.kr/product/177603701_...
#
#                                             url  is_mint   city state
# 0    https://m.bunjang.co.kr/products/188421407        0   충청북도   진천군
# 1    https://m.bunjang.co.kr/products/188824163        0
# 4    https://m.bunjang.co.kr/products/180721599        1    경기도   성남시
# 5    https://m.bunjang.co.kr/products/179149750        0   충청북도   청주시
# 6    https://m.bunjang.co.kr/products/187808246        0  대구광역시   달서구
# ..                                          ...      ...    ...   ...
# 189  https://m.bunjang.co.kr/products/161193954        0
# 191  https://m.bunjang.co.kr/products/168865132        0   경상남도   양산시
# 192  https://m.bunjang.co.kr/products/178358894        0
# 194   https://m.bunjang.co.kr/products/97375194        0
# 199  https://m.bunjang.co.kr/products/177603701        0   경상남도   양산시
#
# [101 rows x 11 columns]

# %%
#컬럼명 변경
final.rename(columns  = {
    'name' : 'title',
    'status':'is_sold',
    'update_time':'upload_date'
}, inplace = True)

# %%
# 스프링서버로부터 post의 크기 받아왔다고 가정
size=125
item_id=11
# post size에 기반한 id열 생성
final['id']=range(size+1,size+1+len(final))
# Out:
# <ipython-input-25-32341bb8f58c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['id']=range(size+1,size+1+len(final))

# %%
#post 데이터 만들기
# item_id ,location_id , market_price_id, platform_id 바꾸는 로직 추가 필요
post_columns=['id','pid','url','is_sold','is_mint','upload_date','title','product_image','city','state'] #platform추가
post=final[post_columns].copy()
post.rename(columns  = {
    'id' : 'post_id',
}, inplace = True)
post['item_id']=11
# post['location_id']=15 # 지역 데이터 앞에 꺼만 뺴오기 수원시 권선구 -> 수원시
post['platform_id']=12
post
# Out:
#      post_id        pid                                         url  is_sold  \
# 0        126  188421407  https://m.bunjang.co.kr/products/188421407        1
# 1        127  188824163  https://m.bunjang.co.kr/products/188824163        1
# 4        128  180721599  https://m.bunjang.co.kr/products/180721599        1
# 5        129  179149750  https://m.bunjang.co.kr/products/179149750        1
# 6        130  187808246  https://m.bunjang.co.kr/products/187808246        1
# ..       ...        ...                                         ...      ...
# 189      222  161193954  https://m.bunjang.co.kr/products/161193954        1
# 191      223  168865132  https://m.bunjang.co.kr/products/168865132        1
# 192      224  178358894  https://m.bunjang.co.kr/products/178358894        1
# 194      225   97375194   https://m.bunjang.co.kr/products/97375194        1
# 199      226  177603701  https://m.bunjang.co.kr/products/177603701        1
#
#      is_mint          upload_date                                     title  \
# 0          0  2022-05-25 04:29:53  맥심 커피 믹스 100개+맥심 모카골드 마일드 75개+신라면 낱개 15개
# 1          0  2022-05-25 03:51:12                   맥심 모카골드 마일드 커피믹스 160스틱
# 4          1  2022-05-25 01:08:26      믹스커피 180+180 모카골드 화이트골드 360T미개봉~새상품~
# 5          0  2022-05-25 12:33:13                        맥심 슈프림골드 커피믹스 170T
# 6          0  2022-05-25 12:23:35                           맥심모카골드커피믹스 180T
# ..       ...                  ...                                       ...
# 189        0  2022-02-14 07:30:07                프렌치커피 믹스 총 340T (170t x 2)
# 191        0  2022-02-13 08:41:02                  커피믹스100믹스 생강차50믹스 종이컵50개
# 192        0  2022-02-10 02:45:59          (무배) 프렌치카페 커피믹스 400T (50T X 8ea)
# 194        0  2022-02-06 04:54:31                            프렌치카페 커피믹스300개
# 199        0  2022-02-01 02:12:20                        커피믹스 300믹스 종이컵300개
#
#                                          product_image   city state  \
# 0    https://media.bunjang.co.kr/product/188421407_...   충청북도   진천군
# 1    https://media.bunjang.co.kr/product/188824163_...
# 4    https://media.bunjang.co.kr/product/180721599_...    경기도   성남시
# 5    https://media.bunjang.co.kr/product/179149750_...   충청북도   청주시
# 6    https://media.bunjang.co.kr/product/187808246_...  대구광역시   달서구
# ..                                                 ...    ...   ...
# 189  https://media.bunjang.co.kr/product/161193954_...
# 191  https://media.bunjang.co.kr/product/168865132_...   경상남도   양산시
# 192  https://media.bunjang.co.kr/product/178358894_...
# 194  https://media.bunjang.co.kr/product/97375194_1...
# 199  https://media.bunjang.co.kr/product/177603701_...   경상남도   양산시
#
#        platform  item_id  platform_id
# 0    Jongo Nara       11           12
# 1    Jongo Nara       11           12
# 4    Jongo Nara       11           12
# 5    Jongo Nara       11           12
# 6    Jongo Nara       11           12
# ..          ...      ...          ...
# 189  Jongo Nara       11           12
# 191  Jongo Nara       11           12
# 192  Jongo Nara       11           12
# 194  Jongo Nara       11           12
# 199  Jongo Nara       11           12
#
# [101 rows x 13 columns]

# %%
#price
price_columns=['id','price'] #platform추가
price=final[price_columns].copy()
price.rename(columns  = {
    'id' : 'price_id',
}, inplace = True)
price['item_id']=11
price
# Out:
#      price_id  price  item_id
# 0         126  30000       11
# 1         127  15510       11
# 4         128  38500       11
# 5         129  20000       11
# 6         130  20000       11
# ..        ...    ...      ...
# 189       222  26000       11
# 191       223  25000       11
# 192       224  29000       11
# 194       225  24000       11
# 199       226  33000       11
#
# [101 rows x 3 columns]

# %%
user='developer', 
password='1234', 
database='dev', 
host='3.36.254.182',
port=13306

conn  = mariadb.connect(
    user='developer', 
    password='1234', 
    database='dev', 
    host='3.36.254.182',
    port=13306
)

# 위 커넥션 정보와 동일하게 입력
engine = create_engine(f"mysql+pymysql://developer:1234@3.36.254.182:13306/dev")
engine
# Out:
# Engine(mysql+pymysql://developer:***@3.36.254.182:13306/dev)

# %%
#조회
# select_sql = "SELECT * FROM post"
# cs = conn.cursor()
# cs.execute(select_sql)
# rs = cs.fetchall()

# 이거는 스프링에서 처리하도록..?
data=(13,strftime('%Y-%m-%d %H:%M:%S', localtime(time())),f"{key_word}")

sql = """
INSERT INTO item (
    item_id,
    latest_search_time,
    name
) VALUES (
    ?, ?, ?
)
"""
cs = conn.cursor()
cs.execute(sql,data)
conn.commit()

# %%
post.drop(['city','state'],axis=1,inplace=True)

# %%
t=time()
post.to_sql('post',engine,if_exists='append',index=False,method='multi')
# price.to_sql('price',engine,if_exists='append',index=False,method='multi')
print(time()-t)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# ~\anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# ~\anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (1054, "Unknown column 'platform' in 'field list'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-44-49af7f12e5f6> in <module>
#       1 t=time()
# ----> 2 post.to_sql('post',engine,if_exists='append',index=False,method='multi')
#       3 # price.to_sql('price',engine,if_exists='append',index=False,method='multi')
#       4 print(time()-t)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert_multi(self, conn, keys, data_iter)
#     756         """
#     757         data = [dict(zip(keys, row)) for row in data_iter]
# --> 758         conn.execute(self.table.insert(data))
#     759
#     760     def insert_data(self):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1274                             break
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#    1278                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# ~\anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# ~\anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1054, "Unknown column 'platform' in 'field list'")
# [SQL: INSERT INTO post (post_id, pid, url, is_sold, is_mint, upload_date, title, product_image, platform, item_id, platform_id) VALUES (%(post_id_m0)s, %(pid_m0)s, %(url_m0)s, %(is_sold_m0)s, %(is_mint_m0)s, %(upload_date_m0)s, %(title_m0)s, %(product_image_m0)s, %(platform_m0)s, %(item_id_m0)s, %(platform_id_m0)s), (%(post_id_m1)s, %(pid_m1)s, %(url_m1)s, %(is_sold_m1)s, %(is_mint_m1)s, %(upload_date_m1)s, %(title_m1)s, %(product_image_m1)s, %(platform_m1)s, %(item_id_m1)s, %(platform_id_m1)s), (%(post_id_m2)s, %(pid_m2)s, %(url_m2)s, %(is_sold_m2)s, %(is_mint_m2)s, %(upload_date_m2)s, %(title_m2)s, %(product_image_m2)s, %(platform_m2)s, %(item_id_m2)s, %(platform_id_m2)s), (%(post_id_m3)s, %(pid_m3)s, %(url_m3)s, %(is_sold_m3)s, %(is_mint_m3)s, %(upload_date_m3)s, %(title_m3)s, %(product_image_m3)s, %(platform_m3)s, %(item_id_m3)s, %(platform_id_m3)s), (%(post_id_m4)s, %(pid_m4)s, %(url_m4)s, %(is_sold_m4)s, %(is_mint_m4)s, %(upload_date_m4)s, %(title_m4)s, %(product_image_m4)s, %(platform_m4)s, %(item_id_m4)s, %(platform_id_m4)s), (%(post_id_m5)s, %(pid_m5)s, %(url_m5)s, %(is_sold_m5)s, %(is_mint_m5)s, %(upload_date_m5)s, %(title_m5)s, %(product_image_m5)s, %(platform_m5)s, %(item_id_m5)s, %(platform_id_m5)s), (%(post_id_m6)s, %(pid_m6)s, %(url_m6)s, %(is_sold_m6)s, %(is_mint_m6)s, %(upload_date_m6)s, %(title_m6)s, %(product_image_m6)s, %(platform_m6)s, %(item_id_m6)s, %(platform_id_m6)s), (%(post_id_m7)s, %(pid_m7)s, %(url_m7)s, %(is_sold_m7)s, %(is_mint_m7)s, %(upload_date_m7)s, %(title_m7)s, %(product_image_m7)s, %(platform_m7)s, %(item_id_m7)s, %(platform_id_m7)s), (%(post_id_m8)s, %(pid_m8)s, %(url_m8)s, %(is_sold_m8)s, %(is_mint_m8)s, %(upload_date_m8)s, %(title_m8)s, %(product_image_m8)s, %(platform_m8)s, %(item_id_m8)s, %(platform_id_m8)s), (%(post_id_m9)s, %(pid_m9)s, %(url_m9)s, %(is_sold_m9)s, %(is_mint_m9)s, %(upload_date_m9)s, %(title_m9)s, %(product_image_m9)s, %(platform_m9)s, %(item_id_m9)s, %(platform_id_m9)s), (%(post_id_m10)s, %(pid_m10)s, %(url_m10)s, %(is_sold_m10)s, %(is_mint_m10)s, %(upload_date_m10)s, %(title_m10)s, %(product_image_m10)s, %(platform_m10)s, %(item_id_m10)s, %(platform_id_m10)s), (%(post_id_m11)s, %(pid_m11)s, %(url_m11)s, %(is_sold_m11)s, %(is_mint_m11)s, %(upload_date_m11)s, %(title_m11)s, %(product_image_m11)s, %(platform_m11)s, %(item_id_m11)s, %(platform_id_m11)s), (%(post_id_m12)s, %(pid_m12)s, %(url_m12)s, %(is_sold_m12)s, %(is_mint_m12)s, %(upload_date_m12)s, %(title_m12)s, %(product_image_m12)s, %(platform_m12)s, %(item_id_m12)s, %(platform_id_m12)s), (%(post_id_m13)s, %(pid_m13)s, %(url_m13)s, %(is_sold_m13)s, %(is_mint_m13)s, %(upload_date_m13)s, %(title_m13)s, %(product_image_m13)s, %(platform_m13)s, %(item_id_m13)s, %(platform_id_m13)s), (%(post_id_m14)s, %(pid_m14)s, %(url_m14)s, %(is_sold_m14)s, %(is_mint_m14)s, %(upload_date_m14)s, %(title_m14)s, %(product_image_m14)s, %(platform_m14)s, %(item_id_m14)s, %(platform_id_m14)s), (%(post_id_m15)s, %(pid_m15)s, %(url_m15)s, %(is_sold_m15)s, %(is_mint_m15)s, %(upload_date_m15)s, %(title_m15)s, %(product_image_m15)s, %(platform_m15)s, %(item_id_m15)s, %(platform_id_m15)s), (%(post_id_m16)s, %(pid_m16)s, %(url_m16)s, %(is_sold_m16)s, %(is_mint_m16)s, %(upload_date_m16)s, %(title_m16)s, %(product_image_m16)s, %(platform_m16)s, %(item_id_m16)s, %(platform_id_m16)s), (%(post_id_m17)s, %(pid_m17)s, %(url_m17)s, %(is_sold_m17)s, %(is_mint_m17)s, %(upload_date_m17)s, %(title_m17)s, %(product_image_m17)s, %(platform_m17)s, %(item_id_m17)s, %(platform_id_m17)s), (%(post_id_m18)s, %(pid_m18)s, %(url_m18)s, %(is_sold_m18)s, %(is_mint_m18)s, %(upload_date_m18)s, %(title_m18)s, %(product_image_m18)s, %(platform_m18)s, %(item_id_m18)s, %(platform_id_m18)s), (%(post_id_m19)s, %(pid_m19)s, %(url_m19)s, %(is_sold_m19)s, %(is_mint_m19)s, %(upload_date_m19)s, %(title_m19)s, %(product_image_m19)s, %(platform_m19)s, %(item_id_m19)s, %(platform_id_m19)s), (%(post_id_m20)s, %(pid_m20)s, %(url_m20)s, %(is_sold_m20)s, %(is_mint_m20)s, %(upload_date_m20 ...
# [parameters: {'post_id_m0': 126, 'pid_m0': '188421407', 'url_m0': 'https://m.bunjang.co.kr/products/188421407', 'is_sold_m0': 1, 'is_mint_m0': 0, 'upload_date_m0': '2022-05-25 04:29:53', 'title_m0': '맥심 커피 믹스 100개+맥심 모카골드 마일드 75개+신라면 낱개 15개', 'product_image_m0': 'https://media.bunjang.co.kr/product/188421407_1_1653051641_w{res}.jpg', 'platform_m0': 'Jongo Nara', 'item_id_m0': 11, 'platform_id_m0': 12, 'post_id_m1': 127, 'pid_m1': '188824163', 'url_m1': 'https://m.bunjang.co.kr/products/188824163', 'is_sold_m1': 1, 'is_mint_m1': 0, 'upload_date_m1': '2022-05-25 03:51:12', 'title_m1': '맥심 모카골드 마일드 커피믹스 160스틱 ', 'product_image_m1': 'https://media.bunjang.co.kr/product/188824163_1_1653451026_w{res}.jpg', 'platform_m1': 'Jongo Nara', 'item_id_m1': 11, 'platform_id_m1': 12, 'post_id_m2': 128, 'pid_m2': '180721599', 'url_m2': 'https://m.bunjang.co.kr/products/180721599', 'is_sold_m2': 1, 'is_mint_m2': 1, 'upload_date_m2': '2022-05-25 01:08:26', 'title_m2': '믹스커피 180+180 모카골드 화이트골드 360T미개봉~새상품~', 'product_image_m2': 'https://media.bunjang.co.kr/product/180721599_1_1649327749_w{res}.jpg', 'platform_m2': 'Jongo Nara', 'item_id_m2': 11, 'platform_id_m2': 12, 'post_id_m3': 129, 'pid_m3': '179149750', 'url_m3': 'https://m.bunjang.co.kr/products/179149750', 'is_sold_m3': 1, 'is_mint_m3': 0, 'upload_date_m3': '2022-05-25 12:33:13', 'title_m3': '맥심 슈프림골드 커피믹스 170T', 'product_image_m3': 'https://media.bunjang.co.kr/product/179149750_1_1652704133_w{res}.jpg', 'platform_m3': 'Jongo Nara', 'item_id_m3': 11, 'platform_id_m3': 12, 'post_id_m4': 130, 'pid_m4': '187808246', 'url_m4': 'https://m.bunjang.co.kr/products/187808246', 'is_sold_m4': 1, 'is_mint_m4': 0, 'upload_date_m4': '2022-05-25 12:23:35', 'title_m4': '맥심모카골드커피믹스 180T', 'product_image_m4': 'https://media.bunjang.co.kr/product/187808246_1_1652496635_w{res}.jpg', 'platform_m4': 'Jongo Nara', 'item_id_m4': 11, 'platform_id_m4': 12, 'post_id_m5': 131, 'pid_m5': '160462916', 'url_m5': 'https://m.bunjang.co.kr/products/160462916', 'is_sold_m5': 1, 'is_mint_m5': 0, 'upload_date_m5': '2022-05-25 10:40:30', 'title_m5': '커피믹스 300 +30개 모카 아라비카', 'product_image_m5': 'https://media.bunjang.co.kr/product/160462916_1_1627624794_w{res}.jpg', 'platform_m5': 'Jongo Nara', 'item_id_m5': 11, 'platform_id_m5': 12, 'post_id_m6': 132, 'pid_m6': '187515924', 'url_m6': 'https://m.bunjang.co.kr/products/187515924', 'is_sold_m6': 1, 'is_mint_m6': 0, 'upload_date_m6': '2022-05-25 12:03:49', 'title_m6': '프렌치카페 믹스커피200개 택포 ', 'product_image_m6': 'https://media.bunjang.co.kr/product/187515924_1_1653451854_w{res}.jpg', 'platform_m6': 'Jongo Nara', 'item_id_m6': 11, 'platform_id_m6': 12, 'post_id_m7': 133, 'pid_m7': '188127115', 'url_m7': 'https://m.bunjang.co.kr/products/188127115', 'is_sold_m7': 1, 'is_mint_m7': 0, 'upload_date_m7': '2022-05-24 07:52:42', 'title_m7': '커피가루(커피믹스4개)', 'product_image_m7': 'https://media.bunjang.co.kr/product/188127115_1_1652859465_w{res}.jpg', 'platform_m7': 'Jongo Nara', 'item_id_m7': 11, 'platform_id_m7': 12, 'post_id_m8': 134, 'pid_m8': '149448862', 'url_m8': 'https://m.bunjang.co.kr/products/149448862', 'is_sold_m8': 1, 'is_mint_m8': 0, 'upload_date_m8': '2022-05-24 01:01:44', 'title_m8': 'G7 3in1 커피믹스 16g 100개 무료배송 g7 믹스커피', 'product_image_m8': 'https://media.bunjang.co.kr/product/149448862_1_1644309776_w{res}.jpg', 'platform_m8': 'Jongo Nara', 'item_id_m8': 11, 'platform_id_m8': 12, 'post_id_m9': 135, 'pid_m9': '180435025', 'url_m9': 'https://m.bunjang.co.kr/products/180435025', 'is_sold_m9': 1, 'is_mint_m9': 1, 'upload_date_m9': '2022-05-24 11:28:11', 'title_m9': '믹스커피 180+180 모카골드 화이트골드 360T미개봉~새상품~', 'product_image_m9': 'https://media.bunjang.co.kr/product/180435025_1_1649327859_w{res}.jpg', 'platform_m9': 'Jongo Nara', 'item_id_m9': 11, 'platform_id_m9': 12, 'post_id_m10': 136, 'pid_m10': '187998805', 'url_m10': 'https://m.bunjang.co.kr/products/187998805', 'is_sold_m10': 1, 'is_mint_m10': 0, 'upload_date_m10': '2022-05-24 10:27:46', 'title_m10': '맥심 모카골드 커피믹스360T', 'product_im ...
# (Background on this error at: http://sqlalche.me/e/13/e3q8)
