# %%
from bs4 import BeautifulSoup
import requests
import urllib.request
import urllib.parse

# %%
search = "아이폰 13"
search = search.replace(" " ,"%20")
url = f"https://www.daangn.com/search/{search}"
response=requests.get(url)
# Out:
# '<!DOCTYPE html>\n<html lang="ko">\n<head>\n  <meta charset="utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no">\n  \n    <link rel="canonical" href="https://www.daangn.com/search/%EC%95%84%EC%9D%B4%ED%8F%B0%2013" />\n\n  <title>아이폰 13 중고거래 | 당신 근처의 당근마켓</title>\n<meta name="description" content="상태 A급!아이폰13프로 iPhone13pro 128기가, 아이폰13 프로맥스 알파인그린 256GB ..." />\n<meta name="keywords" content="아이폰, 13" />\n<link rel="author" href="당근마켓" />\n<meta property="og:url" content="https://www.daangn.com/search/%EC%95%84%EC%9D%B4%ED%8F%B0%2013" />\n<meta property="og:title" content="아이폰 13 중고거래 | 당신 근처의 당근마켓" />\n<meta property="og:description" content="상태 A급!아이폰13프로  iPhone13pro 128기가, 아이폰13 프로맥스 알파인그린 256GB ..." />\n<meta property="og:site_name" content="당근마켓" />\n<meta property="og:image" content="https://www.daangn.com/images/meta/home/daangn.png" />\n<meta property="og:type" content="article" />\n<meta property="og:locale" content="ko_KR" />\n<meta property="fb:app_id" content="1463621440622064" />\n<meta name="twitter:card" content="summary_large_image" />\n<meta name="twitter:site" content="@danggeunmarket" />\n<meta name="twitter:title" content="아이폰 13 중고거래 | 당신 근처의 당근마켓" />\n<meta name="twitter:description" content="상태 A급!아이폰13프로  iPhone13pro 128기가, 아이폰13 프로맥스 알파인그린 256GB ..." />\n<meta name="twitter:image" content="https://www.daangn.com/images/meta/home/daangn.png" />\n<meta name="naver-site-verification" content="d1f8112731c18313535732cf2516d6401bfed40a" />\n  <link href="/images/icons/shortcut_icon.png" rel="shortcut icon" type="image/x-icon">\n  <link rel="shortcut icon" type="image/x-icon" href="https://d1unjqcospf8gs.cloudfront.net/favicon.ico" />\n\n  \n    <link rel="stylesheet" media="all" href="https://d1unjqcospf8gs.cloudfront.net/assets/home/search/index-2a3837ce64a7d2a655be4d2ed01a06f583d0cec3f7da491cfb0cf4f47213906b.css" />\n      <script src="https://d1unjqcospf8gs.cloudfront.net/assets/home/search/index-d6380974d3940f895b97952784380d676c673055edef010e9e6167449d63e4fa.js"></script>\n\n  <link rel="apple-touch-icon" sizes="192x192" href="/images/icons/daangn_logo_192.png">\n  <link rel="apple-touch-icon-precomposed" href="/images/icons/daangn_logo_192.png">\n\n  <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->\n  <!--[if lt IE 9]>\n  <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>\n  <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>\n  <![endif]-->\n  <meta name="csrf-param" content="authenticity_token" />\n<meta name="csrf-token" content="eXQZYpKEMZcgAQv3gq8_HYG1S8JOywx5YpXjNhrzUER8J1cY5bBdjnWeehjTQykXnSnNuLzl9BW_PZt32yw6Fg" />\n  <script>\n    window.fbAsyncInit = function() {\n      FB.init({\n        appId      : \'1463621440622064\',\n        xfbml      : true,\n        version    : \'v2.4\'\n      });\n    };\n\n    (function(d, s, id){\n      var js, fjs = d.getElementsByTagName(s)[0];\n      if (d.getElementById(id)) {return;}\n      js = d.createElement(s); js.id = id;\n      js.src = "//connect.facebook.net/en_US/sdk.js";\n      fjs.parentNode.insertBefore(js, fjs);\n    }(document, \'script\', \'facebook-jssdk\'));\n  </script>\n  <script>\n    (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n              (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n            m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n    })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n    ga(\'create\', \'UA-64551386-2\', \'auto\');\n     ga(\'set\', \'dimension2\', \'false\');  ga(\'send\', \'pageview\'); </script>\n  <!-- Facebook Pixel Code -->\n  <script>\n    !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?\n            n.callMethod.apply(n,arguments):n.qu ...

# %%
# web_url에 원하는 웹의 URL을 넣어주시면 됩니다.
with urllib.request.urlopen(web_url) as response:
    html = response.read()
    soup = BeautifulSoup(html, 'html.parser')
# Out:
# '<!DOCTYPE html>\n<html lang="ko">\n<head>\n  <meta charset="utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no">\n  \n    <link rel="canonical" href="https://www.daangn.com/search/%EC%95%84%EC%9D%B4%ED%8F%B0%2013" />\n\n  <title>아이폰 13 중고거래 | 당신 근처의 당근마켓</title>\n<meta name="description" content="상태 A급!아이폰13프로 iPhone13pro 128기가, 아이폰13 프로맥스 알파인그린 256GB ..." />\n<meta name="keywords" content="아이폰, 13" />\n<link rel="author" href="당근마켓" />\n<meta property="og:url" content="https://www.daangn.com/search/%EC%95%84%EC%9D%B4%ED%8F%B0%2013" />\n<meta property="og:title" content="아이폰 13 중고거래 | 당신 근처의 당근마켓" />\n<meta property="og:description" content="상태 A급!아이폰13프로  iPhone13pro 128기가, 아이폰13 프로맥스 알파인그린 256GB ..." />\n<meta property="og:site_name" content="당근마켓" />\n<meta property="og:image" content="https://www.daangn.com/images/meta/home/daangn.png" />\n<meta property="og:type" content="article" />\n<meta property="og:locale" content="ko_KR" />\n<meta property="fb:app_id" content="1463621440622064" />\n<meta name="twitter:card" content="summary_large_image" />\n<meta name="twitter:site" content="@danggeunmarket" />\n<meta name="twitter:title" content="아이폰 13 중고거래 | 당신 근처의 당근마켓" />\n<meta name="twitter:description" content="상태 A급!아이폰13프로  iPhone13pro 128기가, 아이폰13 프로맥스 알파인그린 256GB ..." />\n<meta name="twitter:image" content="https://www.daangn.com/images/meta/home/daangn.png" />\n<meta name="naver-site-verification" content="d1f8112731c18313535732cf2516d6401bfed40a" />\n  <link href="/images/icons/shortcut_icon.png" rel="shortcut icon" type="image/x-icon">\n  <link rel="shortcut icon" type="image/x-icon" href="https://d1unjqcospf8gs.cloudfront.net/favicon.ico" />\n\n  \n    <link rel="stylesheet" media="all" href="https://d1unjqcospf8gs.cloudfront.net/assets/home/search/index-2a3837ce64a7d2a655be4d2ed01a06f583d0cec3f7da491cfb0cf4f47213906b.css" />\n      <script src="https://d1unjqcospf8gs.cloudfront.net/assets/home/search/index-d6380974d3940f895b97952784380d676c673055edef010e9e6167449d63e4fa.js"></script>\n\n  <link rel="apple-touch-icon" sizes="192x192" href="/images/icons/daangn_logo_192.png">\n  <link rel="apple-touch-icon-precomposed" href="/images/icons/daangn_logo_192.png">\n\n  <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->\n  <!--[if lt IE 9]>\n  <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>\n  <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>\n  <![endif]-->\n  <meta name="csrf-param" content="authenticity_token" />\n<meta name="csrf-token" content="eXQZYpKEMZcgAQv3gq8_HYG1S8JOywx5YpXjNhrzUER8J1cY5bBdjnWeehjTQykXnSnNuLzl9BW_PZt32yw6Fg" />\n  <script>\n    window.fbAsyncInit = function() {\n      FB.init({\n        appId      : \'1463621440622064\',\n        xfbml      : true,\n        version    : \'v2.4\'\n      });\n    };\n\n    (function(d, s, id){\n      var js, fjs = d.getElementsByTagName(s)[0];\n      if (d.getElementById(id)) {return;}\n      js = d.createElement(s); js.id = id;\n      js.src = "//connect.facebook.net/en_US/sdk.js";\n      fjs.parentNode.insertBefore(js, fjs);\n    }(document, \'script\', \'facebook-jssdk\'));\n  </script>\n  <script>\n    (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n              (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n            m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n    })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n    ga(\'create\', \'UA-64551386-2\', \'auto\');\n     ga(\'set\', \'dimension2\', \'false\');  ga(\'send\', \'pageview\'); </script>\n  <!-- Facebook Pixel Code -->\n  <script>\n    !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?\n            n.callMethod.apply(n,arguments):n.qu ...
