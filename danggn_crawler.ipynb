# %%
from bs4 import BeautifulSoup
import requests
import urllib.request
import urllib.parse

# %%
search = "아이폰 13"
search = search.replace(" " ,"%20")
url = f"https://www.daangn.com/search/{search}"
response=requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
# <link href="https://www.daangn.com/search/%EC%95%84%EC%9D%B4%ED%8F%B0%2013" rel="canonical"/>
# <title>아이폰 13 중고거래 | 당신 근처의 당근마켓</title>
# <meta content="아이폰 13프로맥스 투명 카드 케이스 (iPhone 13pro max), 상태 A급!아이폰13프로 i..." name="description">
# <meta content="아이폰, 13" name="keywords">
# <link href="당근마켓" rel="author"/>
# <meta content="https://www.daangn.com/search/%EC%95%84%EC%9D%B4%ED%8F%B0%2013" property="og:url">
# <meta content="아이폰 13 중고거래 | 당신 근처의 당근마켓" property="og:title"/>
# <meta content="아이폰 13프로맥스 투명 카드 케이스 (iPhone 13pro max), 상태 A급!아이폰13프로  i..." property="og:description"/>
# <meta content="당근마켓" property="og:site_name"/>
# <meta content="https://www.daangn.com/images/meta/home/daangn.png" property="og:image"/>
# ...

# %%
# Out:
# [main 5d9604c] feat: �떦洹쇰쭏耳� �겕濡ㅻ쭅 湲곕낯援ъ“ 異붽��
#  3 files changed, 4889 insertions(+)
#  create mode 100644 .ipynb_checkpoints/danggn_crawler-checkpoint.ipynb
#  create mode 100644 12.csv
#  create mode 100644 danggn_crawler.ipynb
